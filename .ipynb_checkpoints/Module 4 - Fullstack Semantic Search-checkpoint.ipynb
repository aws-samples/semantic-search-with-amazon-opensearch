# %% [markdown]
# # Semantic Search with Amazon OpenSearch

# %% [markdown]
# ### Upgrade PyTorch and restart Kernel

# %%
# !pip install --upgrade torch

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()

# %% [markdown]
# ### Verify PyTorch version

# %%
import torch
print(torch.__version__)

# %% [markdown]
# ### Install required libarary, such as HuggingFace

# %%
# !pip install -q transformers
# !pip install -q boto3
# !pip install -q requests
# !pip install -q requests-aws4auth
# !pip install -q opensearch-py
# !pip install -q tqdm
# !pip install -q install transformers[torch]
# !pip install -U sentence-transformers rank_bm25

# %% [markdown]
# ### Initialize Boto3

# %%
import boto3
import re
import time
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()

s3_resource = boto3.resource("s3")
s3 = boto3.client('s3')
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %% [markdown]
# ## Get Cloud Formation stack output variables
#
# ### Note change "cloudformation_stack_name" to the Cloud Formation stack name when you provision your env.

# %%
cfn = boto3.client('cloudformation')

def get_cfn_outputs(stackname):
    outputs = {}
    for output in cfn.describe_stacks(StackName=stackname)['Stacks'][0]['Outputs']:
        outputs[output['OutputKey']] = output['OutputValue']
    return outputs

## Setup variables to use for the rest of the demo
cloudformation_stack_name = "static-cloudformation-semantic-search"

outputs = get_cfn_outputs(cloudformation_stack_name)

bucket = outputs['s3BucketTraining']
aos_host = outputs['DomainEndpoint']

outputs

# %% [markdown]
# ## Step 1: Prepare BERT Model in SageMaker
#
# Use Hugging Face BERT model to generate vectorization data, every sentence is 768 dimention data.
# ![BERT](nlp_bert.png)

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from transformers import DistilBertTokenizer, DistilBertModel

#model_name = "distilbert-base-uncased"
#model_name = "sentence-transformers/msmarco-distilbert-base-dot-prod-v3"
model_name = "sentence-transformers/distilbert-base-nli-stsb-mean-tokens"


#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask


def sentence_to_vector(raw_inputs):
    tokenizer = DistilBertTokenizer.from_pretrained(model_name)
    model = DistilBertModel.from_pretrained(model_name)
    inputs_tokens = tokenizer(raw_inputs, padding=True, return_tensors="pt")
    
    with torch.no_grad():
        outputs = model(**inputs_tokens)

    sentence_embeddings = mean_pooling(outputs, inputs_tokens['attention_mask'])
    return sentence_embeddings

# %% [markdown]
# ### Save pre-trained BERT model to local and then upload to S3
#
# In this section will host the pretrained BERT model into SageMaker Pytorch model server to generate 768x1 dimension fixed length sentence embedding from [sentence-transformers](https://github.com/UKPLab/sentence-transformers) using [HuggingFace Transformers](https://huggingface.co/sentence-transformers/distilbert-base-nli-stsb-mean-tokens).

# %%
import os
from transformers import AutoTokenizer, AutoModel
saved_model_dir = 'transformer'
os.makedirs(saved_model_dir, exist_ok=True)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name) 

tokenizer.save_pretrained(saved_model_dir)
model.save_pretrained(saved_model_dir)

# %%
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# %%
# !cd transformer && tar czvf ../model.tar.gz *

# %%
#Upload the model to S3

inputs = sagemaker_session.upload_data(path='model.tar.gz', key_prefix='sentence-transformers-model')
inputs

# %% [markdown]
# ### Deploy the BERT model to SageMaker Endpoint
#
# First we need to create a PyTorchModel object. The deploy() method on the model object creates an endpoint which serves prediction requests in real-time. If the instance_type is set to a SageMaker instance type (e.g. ml.m5.large) then the model will be deployed on SageMaker. If the instance_type parameter is set to local then it will be deployed locally as a Docker container and ready for testing locally.
#
# First we need to create a Predictor class to accept TEXT as input and output JSON. The default behaviour is to accept a numpy array.

# %%
from sagemaker.pytorch import PyTorch, PyTorchModel
from sagemaker.predictor import Predictor
from sagemaker import get_execution_role

class StringPredictor(Predictor):
    def __init__(self, endpoint_name, sagemaker_session):
        super(StringPredictor, self).__init__(endpoint_name, sagemaker_session, content_type='text/plain')

# %% [markdown]
# Deploy the BERT model to Sagemaker Endpoint
#
# #### Note: This process will take serveral minutes to complete.

# %%
pytorch_model = PyTorchModel(model_data = inputs, 
                             role=role, 
                             entry_point ='inference.py',
                             source_dir = './code',
                             py_version = 'py38', 
                             framework_version = '1.10.2',
                             predictor_cls=StringPredictor)

predictor = pytorch_model.deploy(instance_type='ml.m5d.large', 
                                 initial_instance_count=1, 
                                 endpoint_name = f'semantic-search-model-{int(time.time())}')

# %% [markdown]
# ### Test the SageMaker Endpoint.
#
# Input is text data, output is vector data

# %%
import json
original_payload = 'Does this work with xbox?'
features = predictor.predict(original_payload)
vector_data = json.loads(features)

vector_data

# %% [markdown]
# ## Step 2: Ingest data to OpenSearch Cluster
# Load data set of Amazon Product Question and Answer data from : https://registry.opendata.aws/amazon-pqa/

# %% [markdown]
# ### Downloading Amazon Production Question and Answer Data
#
# Datasets: https://registry.opendata.aws/amazon-pqa/

# %%
# !aws s3 ls --no-sign-request s3://amazon-pqa/

# %%
# !aws s3 cp --no-sign-request s3://amazon-pqa/amazon_pqa_headsets.json ./amazon-pqa/amazon_pqa_headsets.json

# %% [markdown]
# ### We can ingest 1000 rows data for test

# %%
import json
import pandas as pd

def load_pqa(file_name,number_rows=1000):
    qa_list = []
    df = pd.DataFrame(columns=('question', 'answer'))
    with open(file_name) as f:
        i=0
        for line in f:
            data = json.loads(line)
            df.loc[i] = [data['question_text'],data['answers'][0]['answer_text']]
            i+=1
            if(i == number_rows):
                break
    return df


qa_list = load_pqa('amazon-pqa/amazon_pqa_headsets.json',number_rows=1000)

# %% [markdown]
# Convert the text data into vector data

# %%
vector_sentences = sentence_to_vector(qa_list["question"].tolist())

# %% [markdown]
# Use Python API to set up connection with OpenSearch Cluster

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
import boto3

region = 'us-east-1' 

credentials = boto3.Session().get_credentials()
auth = AWSV4SignerAuth(credentials, region)
index_name = 'nlp_pqa'

aos_client = OpenSearch(
    hosts = [{'host': aos_host, 'port': 443}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

# %% [markdown]
# Create a index with 2 fields, the first field is "content" for raw sentece, the second field is "nlp_article_vector" for vector data.

# %%
knn_index = {
    "settings": {
        "index.knn": True,
        "index.knn.space_type": "cosinesimil",
        "analysis": {
          "analyzer": {
            "default": {
              "type": "standard",
              "stopwords": "_english_"
            }
          }
        }
    },
    "mappings": {
        "properties": {
            "question_vector": {
                "type": "knn_vector",
                "dimension": 768,
                "store": True
            },
            "question": {
                "type": "text",
                "store": True
            },
            "answer": {
                "type": "text",
                "store": True
            }
        }
    }
}

# %%
aos_client.indices.delete(index="nlp_pqa")

# %%
aos_client.indices.create(index="nlp_pqa",body=knn_index,ignore=400)

# %% [markdown]
# Show the created index information

# %%
aos_client.indices.get(index="nlp_pqa")

# %%
i = 0
for c in qa_list["question"].tolist():
    content=c
    vector=vector_sentences[i].tolist()
    answer=qa_list["answer"][i]
    i+=1
    aos_client.index(index='nlp_pqa',body={"question_vector": vector, "question": content,"answer":answer})

# %% [markdown]
# ### Ingest all the headset PQA data into OpenSearch Cluster
# Comment out the following code to ingest all the headset question, answer and corresponding question vector data into OpenSearch index.
#
# ### Note: it will take more than 10 minutes to complete.

# %%
# import json
# from tqdm.contrib.concurrent import process_map
# from multiprocessing import cpu_count


# def load_pqa_as_json(file_name):
#     result=[]
#     with open(file_name) as f:
#         for line in f:
#             data = json.loads(line)
#             result.append(data)
#     return result


# qa_list_json = load_pqa_as_json('amazon-pqa/amazon_pqa_headsets.json')


# def es_import(question):
#     vector = json.loads(predictor.predict(question["question_text"]))
#     aos_client.index(index='nlp_pqa',
#              body={"question_vector": vector, "question": question["question_text"],"answer":question["answers"][0]["answer_text"]}
#             )
        
# workers = 4 * cpu_count()
    
# process_map(es_import, qa_list_json, max_workers=workers,chunksize=1000)

# %% [markdown]
# ### Query the documents number in the OpenSearch Cluster

# %%
res = aos_client.search(index="nlp_pqa", body={"query": {"match_all": {}}})
print("Got %d Hits:" % res['hits']['total']['value'])

# %% [markdown]
# ## Step 3: Deploying a full-stack semantic search application
#
# The full stack semantic search applicaiton architecure is as following:
#
# ![full stack semantic search](semantic_search_fullstack.jpg)

# %% [markdown]
# Now that you have a working Amazon SageMaker endpoint for extracting image features and a KNN index on Elasticsearch, you are ready to build a real-world full-stack ML-powered web app. The SAM template you just created will deploy an Amazon API Gateway and AWS Lambda function. The Lambda function runs your code in response to HTTP requests that are sent to the API Gateway.

# %%
# !ls backend/lambda
# Out:
# app.py           build-lambda.sh  requirements.txt

# %%
# %cd backend/lambda
# !sh build-lambda.sh
# Out:
# /Users/lijianwe/Documents/AWS/OpenSearch/ML/semantic-search/code/semantic-search/backend/lambda
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting elasticsearch==7.10
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 317 kB/s eta 0:00:01
# Collecting requests-aws4auth
#   Downloading requests_aws4auth-1.1.2-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<2,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Collecting certifi
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 2.8 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 308 kB/s eta 0:00:01
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, six, requests, requests-aws4auth, elasticsearch
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.5 which is incompatible.
# tensorflow 2.6.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 4.2.0 which is incompatible.
# sphinx 4.0.1 requires Jinja2<3.0,>=2.3, but you have jinja2 3.0.3 which is incompatible.
# sphinx 4.0.1 requires MarkupSafe<2.0, but you have markupsafe 2.0.1 which is incompatible.
# mxnet 1.8.0.post0 requires graphviz<0.9.0,>=0.8.1, but you have graphviz 0.19.1 which is incompatible.
# mlflow 1.21.0 requires alembic<=1.4.1, but you have alembic 1.7.6 which is incompatible.
# azureml-core 1.36.0.post1 requires urllib3<=1.26.7,>=1.23, but you have urllib3 1.26.12 which is incompatible.
# autogluon-text 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-text 0.3.1 requires scipy<1.7,>=1.5.4, but you have scipy 1.7.3 which is incompatible.
# autogluon-tabular 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-tabular 0.3.1 requires scipy<1.7,>=1.5.4, but you have scipy 1.7.3 which is incompatible.
# autogluon-mxnet 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-features 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-extra 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-extra 0.3.1 requires scipy<1.7,>=1.5.4, but you have scipy 1.7.3 which is incompatible.
# autogluon-core 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-core 0.3.1 requires scipy<1.7,>=1.5.4, but you have scipy 1.7.3 which is incompatible.
# autogluon-contrib-nlp 0.0.1b20210201 requires tokenizers==0.9.4, but you have tokenizers 0.11.6 which is incompatible.
# Successfully installed certifi-2022.9.24 charset-normalizer-2.1.1 elasticsearch-7.10.0 idna-3.4 requests-2.28.1 requests-aws4auth-1.1.2 six-1.16.0 urllib3-1.26.12
#   adding: bin/ (stored 0%)
#   adding: bin/normalizer (deflated 27%)
#   adding: charset_normalizer-2.1.1.dist-info/ (stored 0%)
#   adding: charset_normalizer-2.1.1.dist-info/RECORD (deflated 59%)
#   adding: charset_normalizer-2.1.1.dist-info/LICENSE (deflated 41%)
#   adding: charset_normalizer-2.1.1.dist-info/WHEEL (stored 0%)
#   adding: charset_normalizer-2.1.1.dist-info/entry_points.txt (deflated 21%)
#   adding: charset_normalizer-2.1.1.dist-info/top_level.txt (stored 0%)
#   adding: charset_normalizer-2.1.1.dist-info/INSTALLER (stored 0%)
#   adding: charset_normalizer-2.1.1.dist-info/METADATA (deflated 59%)
#   adding: six-1.16.0.dist-info/ (stored 0%)
#   adding: six-1.16.0.dist-info/RECORD (deflated 34%)
#   adding: six-1.16.0.dist-info/LICENSE (deflated 41%)
#   adding: six-1.16.0.dist-info/WHEEL (deflated 14%)
#   adding: six-1.16.0.dist-info/top_level.txt (stored 0%)
#   adding: six-1.16.0.dist-info/INSTALLER (stored 0%)
#   adding: six-1.16.0.dist-info/METADATA (deflated 55%)
#   adding: urllib3-1.26.12.dist-info/ (stored 0%)
#   adding: urllib3-1.26.12.dist-info/RECORD (deflated 62%)
#   adding: urllib3-1.26.12.dist-info/WHEEL (deflated 14%)
#   adding: urllib3-1.26.12.dist-info/top_level.txt (stored 0%)
#   adding: urllib3-1.26.12.dist-info/LICENSE.txt (deflated 41%)
#   adding: urllib3-1.26.12.dist-info/INSTALLER (stored 0%)
#   adding: urllib3-1.26.12.dist-info/METADATA (deflated 65%)
#   adding: idna/ (stored 0%)
#   adding: idna/intranges.py (deflated 57%)
#   adding: idna/package_data.py (stored 0%)
#   adding: idna/compat.py (deflated 40%)
#   adding: idna/idnadata.py (deflated 79%)
#   adding: idna/__init__.py (deflated 67%)
#   adding: idna/core.py (deflated 77%)
#   adding: idna/__pycache__/ (stored 0%)
#   adding: idna/__pycache__/__init__.cpython-38.pyc (deflated 40%)
#   adding: idna/__pycache__/uts46data.cpython-38.pyc (deflated 79%)
#   adding: idna/__pycache__/intranges.cpython-38.pyc (deflated 40%)
#   adding: idna/__pycache__/package_data.cpython-38.pyc (deflated 15%)
#   adding: idna/__pycache__/core.cpython-38.pyc (deflated 51%)
#   adding: idna/__pycache__/idnadata.cpython-38.pyc (deflated 66%)
#   adding: idna/__pycache__/compat.cpython-38.pyc (deflated 37%)
#   adding: idna/__pycache__/codec.cpython-38.pyc (deflated 56%)
#   adding: idna/py.typed (stored 0%)
#   adding: idna/codec.py (deflated 76%)
#   adding: idna/uts46data.py (deflated 80%)
#   adding: certifi-2022.9.24.dist-info/ (stored 0%)
#   adding: certifi-2022.9.24.dist-info/RECORD (deflated 43%)
#   adding: certifi-2022.9.24.dist-info/LICENSE (deflated 43%)
#   adding: certifi-2022.9.24.dist-info/WHEEL (stored 0%)
#   adding: certifi-2022.9.24.dist-info/top_level.txt (stored 0%)
#   adding: certifi-2022.9.24.dist-info/INSTALLER (stored 0%)
#   adding: certifi-2022.9.24.dist-info/METADATA (deflated 58%)
#   adding: __pycache__/ (stored 0%)
#   adding: __pycache__/six.cpython-38.pyc (deflated 58%)
#   adding: idna-3.4.dist-info/ (stored 0%)
#   adding: idna-3.4.dist-info/LICENSE.md (deflated 47%)
#   adding: idna-3.4.dist-info/RECORD (deflated 47%)
#   adding: idna-3.4.dist-info/WHEEL (stored 0%)
#   adding: idna-3.4.dist-info/INSTALLER (stored 0%)
#   adding: idna-3.4.dist-info/METADATA (deflated 61%)
#   adding: elasticsearch-7.10.0.dist-info/ (stored 0%)
#   adding: elasticsearch-7.10.0.dist-info/RECORD (deflated 62%)
#   adding: elasticsearch-7.10.0.dist-info/LICENSE (deflated 65%)
#   adding: elasticsearch-7.10.0.dist-info/AUTHORS (deflated 25%)
#   adding: elasticsearch-7.10.0.dist-info/WHEEL (deflated 14%)
#   adding: elasticsearch-7.10.0.dist-info/top_level.txt (stored 0%)
#   adding: elasticsearch-7.10.0.dist-info/REQUESTED (stored 0%)
#   adding: elasticsearch-7.10.0.dist-info/INSTALLER (stored 0%)
#   adding: elasticsearch-7.10.0.dist-info/METADATA (deflated 63%)
#   adding: charset_normalizer/ (stored 0%)
#   adding: charset_normalizer/md.py (deflated 81%)
#   adding: charset_normalizer/version.py (deflated 19%)
#   adding: charset_normalizer/legacy.py (deflated 70%)
#   adding: charset_normalizer/models.py (deflated 72%)
#   adding: charset_normalizer/__init__.py (deflated 53%)
#   adding: charset_normalizer/__pycache__/ (stored 0%)
#   adding: charset_normalizer/__pycache__/api.cpython-38.pyc (deflated 49%)
#   adding: charset_normalizer/__pycache__/__init__.cpython-38.pyc (deflated 40%)
#   adding: charset_normalizer/__pycache__/legacy.cpython-38.pyc (deflated 50%)
#   adding: charset_normalizer/__pycache__/constant.cpython-38.pyc (deflated 52%)
#   adding: charset_normalizer/__pycache__/utils.cpython-38.pyc (deflated 51%)
#   adding: charset_normalizer/__pycache__/models.cpython-38.pyc (deflated 57%)
#   adding: charset_normalizer/__pycache__/cd.cpython-38.pyc (deflated 49%)
#   adding: charset_normalizer/__pycache__/version.cpython-38.pyc (deflated 15%)
#   adding: charset_normalizer/__pycache__/md.cpython-38.pyc (deflated 62%)
#   adding: charset_normalizer/cli/ (stored 0%)
#   adding: charset_normalizer/cli/__init__.py (stored 0%)
#   adding: charset_normalizer/cli/__pycache__/ (stored 0%)
#   adding: charset_normalizer/cli/__pycache__/__init__.cpython-38.pyc (deflated 18%)
#   adding: charset_normalizer/cli/__pycache__/normalizer.cpython-38.pyc (deflated 43%)
#   adding: charset_normalizer/cli/normalizer.py (deflated 73%)
#   adding: charset_normalizer/api.py (deflated 75%)
#   adding: charset_normalizer/utils.py (deflated 74%)
#   adding: charset_normalizer/py.typed (stored 0%)
#   adding: charset_normalizer/constant.py (deflated 70%)
#   adding: charset_normalizer/assets/ (stored 0%)
#   adding: charset_normalizer/assets/__init__.py (deflated 84%)
#   adding: charset_normalizer/assets/__pycache__/ (stored 0%)
#   adding: charset_normalizer/assets/__pycache__/__init__.cpython-38.pyc (deflated 60%)
#   adding: charset_normalizer/cd.py (deflated 74%)
#   adding: requests/ (stored 0%)
#   adding: requests/cookies.py (deflated 73%)
#   adding: requests/auth.py (deflated 71%)
#   adding: requests/sessions.py (deflated 72%)
#   adding: requests/hooks.py (deflated 51%)
#   adding: requests/compat.py (deflated 57%)
#   adding: requests/models.py (deflated 72%)
#   adding: requests/certs.py (deflated 36%)
#   adding: requests/__init__.py (deflated 64%)
#   adding: requests/status_codes.py (deflated 61%)
#   adding: requests/packages.py (deflated 53%)
#   adding: requests/__version__.py (deflated 40%)
#   adding: requests/__pycache__/ (stored 0%)
#   adding: requests/__pycache__/api.cpython-38.pyc (deflated 69%)
#   adding: requests/__pycache__/__init__.cpython-38.pyc (deflated 41%)
#   adding: requests/__pycache__/cookies.cpython-38.pyc (deflated 60%)
#   adding: requests/__pycache__/auth.cpython-38.pyc (deflated 53%)
#   adding: requests/__pycache__/hooks.cpython-38.pyc (deflated 36%)
#   adding: requests/__pycache__/utils.cpython-38.pyc (deflated 51%)
#   adding: requests/__pycache__/adapters.cpython-38.pyc (deflated 58%)
#   adding: requests/__pycache__/packages.cpython-38.pyc (deflated 26%)
#   adding: requests/__pycache__/models.cpython-38.pyc (deflated 54%)
#   adding: requests/__pycache__/compat.cpython-38.pyc (deflated 35%)
#   adding: requests/__pycache__/structures.cpython-38.pyc (deflated 55%)
#   adding: requests/__pycache__/certs.cpython-38.pyc (deflated 29%)
#   adding: requests/__pycache__/exceptions.cpython-38.pyc (deflated 62%)
#   adding: requests/__pycache__/__version__.cpython-38.pyc (deflated 26%)
#   adding: requests/__pycache__/status_codes.cpython-38.pyc (deflated 47%)
#   adding: requests/__pycache__/sessions.cpython-38.pyc (deflated 56%)
#   adding: requests/__pycache__/_internal_utils.cpython-38.pyc (deflated 38%)
#   adding: requests/__pycache__/help.cpython-38.pyc (deflated 43%)
#   adding: requests/api.py (deflated 74%)
#   adding: requests/_internal_utils.py (deflated 55%)
#   adding: requests/utils.py (deflated 68%)
#   adding: requests/exceptions.py (deflated 67%)
#   adding: requests/structures.py (deflated 62%)
#   adding: requests/help.py (deflated 70%)
#   adding: requests/adapters.py (deflated 75%)
#   adding: certifi/ (stored 0%)
#   adding: certifi/__init__.py (deflated 13%)
#   adding: certifi/core.py (deflated 71%)
#   adding: certifi/__pycache__/ (stored 0%)
#   adding: certifi/__pycache__/__init__.cpython-38.pyc (deflated 19%)
#   adding: certifi/__pycache__/core.cpython-38.pyc (deflated 44%)
#   adding: certifi/__pycache__/__main__.cpython-38.pyc (deflated 24%)
#   adding: certifi/py.typed (stored 0%)
#   adding: certifi/cacert.pem (deflated 46%)
#   adding: certifi/__main__.py (deflated 39%)
#   adding: requests_aws4auth-1.1.2.dist-info/ (stored 0%)
#   adding: requests_aws4auth-1.1.2.dist-info/RECORD (deflated 52%)
#   adding: requests_aws4auth-1.1.2.dist-info/LICENSE (deflated 41%)
#   adding: requests_aws4auth-1.1.2.dist-info/WHEEL (deflated 14%)
#   adding: requests_aws4auth-1.1.2.dist-info/top_level.txt (stored 0%)
#   adding: requests_aws4auth-1.1.2.dist-info/REQUESTED (stored 0%)
#   adding: requests_aws4auth-1.1.2.dist-info/INSTALLER (stored 0%)
#   adding: requests_aws4auth-1.1.2.dist-info/METADATA (deflated 62%)
#   adding: requests_aws4auth/ (stored 0%)
#   adding: requests_aws4auth/__init__.py (deflated 58%)
#   adding: requests_aws4auth/__pycache__/ (stored 0%)
#   adding: requests_aws4auth/__pycache__/__init__.cpython-38.pyc (deflated 56%)
#   adding: requests_aws4auth/__pycache__/aws4auth.cpython-38.pyc (deflated 61%)
#   adding: requests_aws4auth/__pycache__/aws4signingkey.cpython-38.pyc (deflated 56%)
#   adding: requests_aws4auth/__pycache__/exceptions.cpython-38.pyc (deflated 48%)
#   adding: requests_aws4auth/aws4auth.py (deflated 72%)
#   adding: requests_aws4auth/aws4signingkey.py (deflated 65%)
#   adding: requests_aws4auth/exceptions.py (deflated 47%)
#   adding: six.py (deflated 76%)
#   adding: urllib3/ (stored 0%)
#   adding: urllib3/filepost.py (deflated 63%)
#   adding: urllib3/fields.py (deflated 70%)
#   adding: urllib3/util/ (stored 0%)
#   adding: urllib3/util/queue.py (deflated 49%)
#   adding: urllib3/util/ssltransport.py (deflated 70%)
#   adding: urllib3/util/proxy.py (deflated 62%)
#   adding: urllib3/util/wait.py (deflated 63%)
#   adding: urllib3/util/request.py (deflated 64%)
#   adding: urllib3/util/timeout.py (deflated 70%)
#   adding: urllib3/util/__init__.py (deflated 59%)
#   adding: urllib3/util/response.py (deflated 61%)
#   adding: urllib3/util/ssl_.py (deflated 66%)
#   adding: urllib3/util/__pycache__/ (stored 0%)
#   adding: urllib3/util/__pycache__/__init__.cpython-38.pyc (deflated 33%)
#   adding: urllib3/util/__pycache__/queue.cpython-38.pyc (deflated 44%)
#   adding: urllib3/util/__pycache__/ssl_.cpython-38.pyc (deflated 50%)
#   adding: urllib3/util/__pycache__/retry.cpython-38.pyc (deflated 57%)
#   adding: urllib3/util/__pycache__/wait.cpython-38.pyc (deflated 46%)
#   adding: urllib3/util/__pycache__/ssltransport.cpython-38.pyc (deflated 54%)
#   adding: urllib3/util/__pycache__/ssl_match_hostname.cpython-38.pyc (deflated 39%)
#   adding: urllib3/util/__pycache__/connection.cpython-38.pyc (deflated 40%)
#   adding: urllib3/util/__pycache__/url.cpython-38.pyc (deflated 46%)
#   adding: urllib3/util/__pycache__/request.cpython-38.pyc (deflated 46%)
#   adding: urllib3/util/__pycache__/proxy.cpython-38.pyc (deflated 40%)
#   adding: urllib3/util/__pycache__/response.cpython-38.pyc (deflated 42%)
#   adding: urllib3/util/__pycache__/timeout.cpython-38.pyc (deflated 60%)
#   adding: urllib3/util/retry.py (deflated 73%)
#   adding: urllib3/util/url.py (deflated 66%)
#   adding: urllib3/util/connection.py (deflated 60%)
#   adding: urllib3/util/ssl_match_hostname.py (deflated 60%)
#   adding: urllib3/_version.py (stored 0%)
#   adding: urllib3/request.py (deflated 67%)
#   adding: urllib3/__init__.py (deflated 58%)
#   adding: urllib3/poolmanager.py (deflated 71%)
#   adding: urllib3/response.py (deflated 73%)
#   adding: urllib3/__pycache__/ (stored 0%)
#   adding: urllib3/__pycache__/__init__.cpython-38.pyc (deflated 39%)
#   adding: urllib3/__pycache__/fields.cpython-38.pyc (deflated 55%)
#   adding: urllib3/__pycache__/_collections.cpython-38.pyc (deflated 54%)
#   adding: urllib3/__pycache__/connectionpool.cpython-38.pyc (deflated 56%)
#   adding: urllib3/__pycache__/connection.cpython-38.pyc (deflated 48%)
#   adding: urllib3/__pycache__/filepost.cpython-38.pyc (deflated 46%)
#   adding: urllib3/__pycache__/request.cpython-38.pyc (deflated 55%)
#   adding: urllib3/__pycache__/_version.cpython-38.pyc (deflated 16%)
#   adding: urllib3/__pycache__/exceptions.cpython-38.pyc (deflated 63%)
#   adding: urllib3/__pycache__/response.cpython-38.pyc (deflated 55%)
#   adding: urllib3/__pycache__/poolmanager.cpython-38.pyc (deflated 55%)
#   adding: urllib3/contrib/ (stored 0%)
#   adding: urllib3/contrib/securetransport.py (deflated 72%)
#   adding: urllib3/contrib/__init__.py (stored 0%)
#   adding: urllib3/contrib/__pycache__/ (stored 0%)
#   adding: urllib3/contrib/__pycache__/pyopenssl.cpython-38.pyc (deflated 52%)
#   adding: urllib3/contrib/__pycache__/__init__.cpython-38.pyc (deflated 18%)
#   adding: urllib3/contrib/__pycache__/_appengine_environ.cpython-38.pyc (deflated 43%)
#   adding: urllib3/contrib/__pycache__/socks.cpython-38.pyc (deflated 50%)
#   adding: urllib3/contrib/__pycache__/securetransport.cpython-38.pyc (deflated 54%)
#   adding: urllib3/contrib/__pycache__/appengine.cpython-38.pyc (deflated 51%)
#   adding: urllib3/contrib/__pycache__/ntlmpool.cpython-38.pyc (deflated 41%)
#   adding: urllib3/contrib/socks.py (deflated 70%)
#   adding: urllib3/contrib/_appengine_environ.py (deflated 54%)
#   adding: urllib3/contrib/pyopenssl.py (deflated 69%)
#   adding: urllib3/contrib/appengine.py (deflated 71%)
#   adding: urllib3/contrib/_securetransport/ (stored 0%)
#   adding: urllib3/contrib/_securetransport/__init__.py (stored 0%)
#   adding: urllib3/contrib/_securetransport/__pycache__/ (stored 0%)
#   adding: urllib3/contrib/_securetransport/__pycache__/__init__.cpython-38.pyc (deflated 19%)
#   adding: urllib3/contrib/_securetransport/__pycache__/bindings.cpython-38.pyc (deflated 52%)
#   adding: urllib3/contrib/_securetransport/__pycache__/low_level.cpython-38.pyc (deflated 49%)
#   adding: urllib3/contrib/_securetransport/low_level.py (deflated 68%)
#   adding: urllib3/contrib/_securetransport/bindings.py (deflated 75%)
#   adding: urllib3/contrib/ntlmpool.py (deflated 64%)
#   adding: urllib3/connection.py (deflated 71%)
#   adding: urllib3/_collections.py (deflated 69%)
#   adding: urllib3/packages/ (stored 0%)
#   adding: urllib3/packages/__init__.py (stored 0%)
#   adding: urllib3/packages/__pycache__/ (stored 0%)
#   adding: urllib3/packages/__pycache__/__init__.cpython-38.pyc (deflated 18%)
#   adding: urllib3/packages/__pycache__/six.cpython-38.pyc (deflated 58%)
#   adding: urllib3/packages/backports/ (stored 0%)
#   adding: urllib3/packages/backports/__init__.py (stored 0%)
#   adding: urllib3/packages/backports/__pycache__/ (stored 0%)
#   adding: urllib3/packages/backports/__pycache__/__init__.cpython-38.pyc (deflated 18%)
#   adding: urllib3/packages/backports/__pycache__/makefile.cpython-38.pyc (deflated 33%)
#   adding: urllib3/packages/backports/makefile.py (deflated 59%)
#   adding: urllib3/packages/six.py (deflated 75%)
#   adding: urllib3/exceptions.py (deflated 69%)
#   adding: urllib3/connectionpool.py (deflated 73%)
#   adding: elasticsearch/ (stored 0%)
#   adding: elasticsearch/transport.pyi (deflated 66%)
#   adding: elasticsearch/compat.py (deflated 52%)
#   adding: elasticsearch/connection/ (stored 0%)
#   adding: elasticsearch/connection/pooling.pyi (deflated 48%)
#   adding: elasticsearch/connection/base.pyi (deflated 65%)
#   adding: elasticsearch/connection/http_urllib3.pyi (deflated 57%)
#   adding: elasticsearch/connection/__init__.pyi (deflated 48%)
#   adding: elasticsearch/connection/http_requests.pyi (deflated 54%)
#   adding: elasticsearch/connection/pooling.py (deflated 54%)
#   adding: elasticsearch/connection/__init__.py (deflated 48%)
#   adding: elasticsearch/connection/__pycache__/ (stored 0%)
#   adding: elasticsearch/connection/__pycache__/__init__.cpython-38.pyc (deflated 27%)
#   adding: elasticsearch/connection/__pycache__/http_requests.cpython-38.pyc (deflated 45%)
#   adding: elasticsearch/connection/__pycache__/base.cpython-38.pyc (deflated 44%)
#   adding: elasticsearch/connection/__pycache__/pooling.cpython-38.pyc (deflated 47%)
#   adding: elasticsearch/connection/__pycache__/http_urllib3.cpython-38.pyc (deflated 47%)
#   adding: elasticsearch/connection/http_urllib3.py (deflated 67%)
#   adding: elasticsearch/connection/base.py (deflated 66%)
#   adding: elasticsearch/connection/http_requests.py (deflated 67%)
#   adding: elasticsearch/__init__.pyi (deflated 61%)
#   adding: elasticsearch/_version.py (deflated 42%)
#   adding: elasticsearch/transport.py (deflated 70%)
#   adding: elasticsearch/_async/ (stored 0%)
#   adding: elasticsearch/_async/transport.pyi (deflated 65%)
#   adding: elasticsearch/_async/compat.py (deflated 47%)
#   adding: elasticsearch/_async/transport.py (deflated 69%)
#   adding: elasticsearch/_async/http_aiohttp.pyi (deflated 60%)
#   adding: elasticsearch/_async/helpers.pyi (deflated 66%)
#   adding: elasticsearch/_async/__init__.py (deflated 42%)
#   adding: elasticsearch/_async/compat.pyi (deflated 42%)
#   adding: elasticsearch/_async/__pycache__/ (stored 0%)
#   adding: elasticsearch/_async/__pycache__/__init__.cpython-38.pyc (deflated 17%)
#   adding: elasticsearch/_async/__pycache__/helpers.cpython-38.pyc (deflated 55%)
#   adding: elasticsearch/_async/__pycache__/transport.cpython-38.pyc (deflated 52%)
#   adding: elasticsearch/_async/__pycache__/_extra_imports.cpython-38.pyc (deflated 24%)
#   adding: elasticsearch/_async/__pycache__/compat.cpython-38.pyc (deflated 25%)
#   adding: elasticsearch/_async/__pycache__/http_aiohttp.cpython-38.pyc (deflated 48%)
#   adding: elasticsearch/_async/http_aiohttp.py (deflated 67%)
#   adding: elasticsearch/_async/_extra_imports.py (deflated 50%)
#   adding: elasticsearch/_async/helpers.py (deflated 69%)
#   adding: elasticsearch/_async/client/ (stored 0%)
#   adding: elasticsearch/_async/client/searchable_snapshots.pyi (deflated 77%)
#   adding: elasticsearch/_async/client/xpack.pyi (deflated 65%)
#   adding: elasticsearch/_async/client/rollup.py (deflated 77%)
#   adding: elasticsearch/_async/client/ingest.py (deflated 72%)
#   adding: elasticsearch/_async/client/license.pyi (deflated 84%)
#   adding: elasticsearch/_async/client/async_search.pyi (deflated 76%)
#   adding: elasticsearch/_async/client/ssl.pyi (deflated 54%)
#   adding: elasticsearch/_async/client/tasks.py (deflated 69%)
#   adding: elasticsearch/_async/client/slm.py (deflated 78%)
#   adding: elasticsearch/_async/client/cat.pyi (deflated 94%)
#   adding: elasticsearch/_async/client/ilm.pyi (deflated 87%)
#   adding: elasticsearch/_async/client/__init__.pyi (deflated 93%)
#   adding: elasticsearch/_async/client/graph.pyi (deflated 56%)
#   adding: elasticsearch/_async/client/enrich.py (deflated 71%)
#   adding: elasticsearch/_async/client/eql.py (deflated 68%)
#   adding: elasticsearch/_async/client/deprecation.py (deflated 48%)
#   adding: elasticsearch/_async/client/remote.py (deflated 46%)
#   adding: elasticsearch/_async/client/dangling_indices.py (deflated 68%)
#   adding: elasticsearch/_async/client/eql.pyi (deflated 74%)
#   adding: elasticsearch/_async/client/cat.py (deflated 88%)
#   adding: elasticsearch/_async/client/nodes.pyi (deflated 81%)
#   adding: elasticsearch/_async/client/monitoring.py (deflated 51%)
#   adding: elasticsearch/_async/client/async_search.py (deflated 69%)
#   adding: elasticsearch/_async/client/autoscaling.pyi (deflated 77%)
#   adding: elasticsearch/_async/client/migration.pyi (deflated 54%)
#   adding: elasticsearch/_async/client/graph.py (deflated 52%)
#   adding: elasticsearch/_async/client/security.py (deflated 89%)
#   adding: elasticsearch/_async/client/xpack.py (deflated 56%)
#   adding: elasticsearch/_async/client/indices.pyi (deflated 95%)
#   adding: elasticsearch/_async/client/deprecation.pyi (deflated 54%)
#   adding: elasticsearch/_async/client/slm.pyi (deflated 87%)
#   adding: elasticsearch/_async/client/security.pyi (deflated 94%)
#   adding: elasticsearch/_async/client/__init__.py (deflated 86%)
#   adding: elasticsearch/_async/client/rollup.pyi (deflated 85%)
#   adding: elasticsearch/_async/client/__pycache__/ (stored 0%)
#   adding: elasticsearch/_async/client/__pycache__/graph.cpython-38.pyc (deflated 41%)
#   adding: elasticsearch/_async/client/__pycache__/transform.cpython-38.pyc (deflated 69%)
#   adding: elasticsearch/_async/client/__pycache__/__init__.cpython-38.pyc (deflated 81%)
#   adding: elasticsearch/_async/client/__pycache__/xpack.cpython-38.pyc (deflated 49%)
#   adding: elasticsearch/_async/client/__pycache__/snapshot.cpython-38.pyc (deflated 74%)
#   adding: elasticsearch/_async/client/__pycache__/ccr.cpython-38.pyc (deflated 71%)
#   adding: elasticsearch/_async/client/__pycache__/watcher.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/_async/client/__pycache__/data_frame.cpython-38.pyc (deflated 65%)
#   adding: elasticsearch/_async/client/__pycache__/eql.cpython-38.pyc (deflated 59%)
#   adding: elasticsearch/_async/client/__pycache__/async_search.cpython-38.pyc (deflated 64%)
#   adding: elasticsearch/_async/client/__pycache__/indices.cpython-38.pyc (deflated 84%)
#   adding: elasticsearch/_async/client/__pycache__/rollup.cpython-38.pyc (deflated 68%)
#   adding: elasticsearch/_async/client/__pycache__/tasks.cpython-38.pyc (deflated 60%)
#   adding: elasticsearch/_async/client/__pycache__/nodes.cpython-38.pyc (deflated 67%)
#   adding: elasticsearch/_async/client/__pycache__/utils.cpython-38.pyc (deflated 20%)
#   adding: elasticsearch/_async/client/__pycache__/ssl.cpython-38.pyc (deflated 36%)
#   adding: elasticsearch/_async/client/__pycache__/migration.cpython-38.pyc (deflated 38%)
#   adding: elasticsearch/_async/client/__pycache__/security.cpython-38.pyc (deflated 81%)
#   adding: elasticsearch/_async/client/__pycache__/searchable_snapshots.cpython-38.pyc (deflated 61%)
#   adding: elasticsearch/_async/client/__pycache__/remote.cpython-38.pyc (deflated 34%)
#   adding: elasticsearch/_async/client/__pycache__/license.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/_async/client/__pycache__/sql.cpython-38.pyc (deflated 54%)
#   adding: elasticsearch/_async/client/__pycache__/monitoring.cpython-38.pyc (deflated 41%)
#   adding: elasticsearch/_async/client/__pycache__/slm.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/_async/client/__pycache__/cat.cpython-38.pyc (deflated 84%)
#   adding: elasticsearch/_async/client/__pycache__/ilm.cpython-38.pyc (deflated 67%)
#   adding: elasticsearch/_async/client/__pycache__/autoscaling.cpython-38.pyc (deflated 64%)
#   adding: elasticsearch/_async/client/__pycache__/dangling_indices.cpython-38.pyc (deflated 59%)
#   adding: elasticsearch/_async/client/__pycache__/deprecation.cpython-38.pyc (deflated 36%)
#   adding: elasticsearch/_async/client/__pycache__/ingest.cpython-38.pyc (deflated 60%)
#   adding: elasticsearch/_async/client/__pycache__/cluster.cpython-38.pyc (deflated 72%)
#   adding: elasticsearch/_async/client/__pycache__/ml.cpython-38.pyc (deflated 80%)
#   adding: elasticsearch/_async/client/__pycache__/enrich.cpython-38.pyc (deflated 58%)
#   adding: elasticsearch/_async/client/ml.pyi (deflated 95%)
#   adding: elasticsearch/_async/client/utils.pyi (deflated 49%)
#   adding: elasticsearch/_async/client/ml.py (deflated 88%)
#   adding: elasticsearch/_async/client/ingest.pyi (deflated 81%)
#   adding: elasticsearch/_async/client/data_frame.pyi (deflated 84%)
#   adding: elasticsearch/_async/client/ccr.py (deflated 81%)
#   adding: elasticsearch/_async/client/utils.py (deflated 42%)
#   adding: elasticsearch/_async/client/cluster.py (deflated 80%)
#   adding: elasticsearch/_async/client/data_frame.py (deflated 78%)
#   adding: elasticsearch/_async/client/cluster.pyi (deflated 90%)
#   adding: elasticsearch/_async/client/transform.py (deflated 80%)
#   adding: elasticsearch/_async/client/watcher.pyi (deflated 88%)
#   adding: elasticsearch/_async/client/indices.py (deflated 89%)
#   adding: elasticsearch/_async/client/license.py (deflated 74%)
#   adding: elasticsearch/_async/client/ccr.pyi (deflated 90%)
#   adding: elasticsearch/_async/client/watcher.py (deflated 78%)
#   adding: elasticsearch/_async/client/sql.py (deflated 65%)
#   adding: elasticsearch/_async/client/ilm.py (deflated 78%)
#   adding: elasticsearch/_async/client/nodes.py (deflated 73%)
#   adding: elasticsearch/_async/client/monitoring.pyi (deflated 56%)
#   adding: elasticsearch/_async/client/searchable_snapshots.py (deflated 70%)
#   adding: elasticsearch/_async/client/ssl.py (deflated 46%)
#   adding: elasticsearch/_async/client/remote.pyi (deflated 52%)
#   adding: elasticsearch/_async/client/migration.py (deflated 48%)
#   adding: elasticsearch/_async/client/enrich.pyi (deflated 80%)
#   adding: elasticsearch/_async/client/autoscaling.py (deflated 73%)
#   adding: elasticsearch/_async/client/tasks.pyi (deflated 75%)
#   adding: elasticsearch/_async/client/dangling_indices.pyi (deflated 74%)
#   adding: elasticsearch/_async/client/sql.pyi (deflated 72%)
#   adding: elasticsearch/_async/client/transform.pyi (deflated 86%)
#   adding: elasticsearch/_async/client/snapshot.py (deflated 85%)
#   adding: elasticsearch/_async/client/snapshot.pyi (deflated 89%)
#   adding: elasticsearch/exceptions.pyi (deflated 58%)
#   adding: elasticsearch/__init__.py (deflated 60%)
#   adding: elasticsearch/compat.pyi (deflated 54%)
#   adding: elasticsearch/__pycache__/ (stored 0%)
#   adding: elasticsearch/__pycache__/__init__.cpython-38.pyc (deflated 41%)
#   adding: elasticsearch/__pycache__/transport.cpython-38.pyc (deflated 54%)
#   adding: elasticsearch/__pycache__/compat.cpython-38.pyc (deflated 32%)
#   adding: elasticsearch/__pycache__/connection_pool.cpython-38.pyc (deflated 58%)
#   adding: elasticsearch/__pycache__/_version.cpython-38.pyc (deflated 15%)
#   adding: elasticsearch/__pycache__/serializer.cpython-38.pyc (deflated 49%)
#   adding: elasticsearch/__pycache__/exceptions.cpython-38.pyc (deflated 59%)
#   adding: elasticsearch/py.typed (stored 0%)
#   adding: elasticsearch/serializer.pyi (deflated 57%)
#   adding: elasticsearch/serializer.py (deflated 67%)
#   adding: elasticsearch/exceptions.py (deflated 66%)
#   adding: elasticsearch/connection_pool.pyi (deflated 66%)
#   adding: elasticsearch/client/ (stored 0%)
#   adding: elasticsearch/client/searchable_snapshots.pyi (deflated 77%)
#   adding: elasticsearch/client/xpack.pyi (deflated 65%)
#   adding: elasticsearch/client/rollup.py (deflated 77%)
#   adding: elasticsearch/client/ingest.py (deflated 72%)
#   adding: elasticsearch/client/license.pyi (deflated 84%)
#   adding: elasticsearch/client/async_search.pyi (deflated 76%)
#   adding: elasticsearch/client/ssl.pyi (deflated 54%)
#   adding: elasticsearch/client/tasks.py (deflated 68%)
#   adding: elasticsearch/client/slm.py (deflated 77%)
#   adding: elasticsearch/client/cat.pyi (deflated 94%)
#   adding: elasticsearch/client/ilm.pyi (deflated 87%)
#   adding: elasticsearch/client/__init__.pyi (deflated 93%)
#   adding: elasticsearch/client/graph.pyi (deflated 56%)
#   adding: elasticsearch/client/enrich.py (deflated 71%)
#   adding: elasticsearch/client/eql.py (deflated 68%)
#   adding: elasticsearch/client/deprecation.py (deflated 48%)
#   adding: elasticsearch/client/remote.py (deflated 46%)
#   adding: elasticsearch/client/dangling_indices.py (deflated 68%)
#   adding: elasticsearch/client/eql.pyi (deflated 74%)
#   adding: elasticsearch/client/cat.py (deflated 88%)
#   adding: elasticsearch/client/nodes.pyi (deflated 81%)
#   adding: elasticsearch/client/monitoring.py (deflated 51%)
#   adding: elasticsearch/client/async_search.py (deflated 69%)
#   adding: elasticsearch/client/autoscaling.pyi (deflated 77%)
#   adding: elasticsearch/client/migration.pyi (deflated 54%)
#   adding: elasticsearch/client/graph.py (deflated 52%)
#   adding: elasticsearch/client/security.py (deflated 89%)
#   adding: elasticsearch/client/xpack.py (deflated 56%)
#   adding: elasticsearch/client/indices.pyi (deflated 95%)
#   adding: elasticsearch/client/deprecation.pyi (deflated 54%)
#   adding: elasticsearch/client/slm.pyi (deflated 87%)
#   adding: elasticsearch/client/security.pyi (deflated 94%)
#   adding: elasticsearch/client/__init__.py (deflated 86%)
#   adding: elasticsearch/client/rollup.pyi (deflated 85%)
#   adding: elasticsearch/client/__pycache__/ (stored 0%)
#   adding: elasticsearch/client/__pycache__/graph.cpython-38.pyc (deflated 42%)
#   adding: elasticsearch/client/__pycache__/transform.cpython-38.pyc (deflated 69%)
#   adding: elasticsearch/client/__pycache__/__init__.cpython-38.pyc (deflated 81%)
#   adding: elasticsearch/client/__pycache__/xpack.cpython-38.pyc (deflated 49%)
#   adding: elasticsearch/client/__pycache__/snapshot.cpython-38.pyc (deflated 74%)
#   adding: elasticsearch/client/__pycache__/ccr.cpython-38.pyc (deflated 71%)
#   adding: elasticsearch/client/__pycache__/watcher.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/client/__pycache__/data_frame.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/client/__pycache__/eql.cpython-38.pyc (deflated 59%)
#   adding: elasticsearch/client/__pycache__/async_search.cpython-38.pyc (deflated 64%)
#   adding: elasticsearch/client/__pycache__/indices.cpython-38.pyc (deflated 84%)
#   adding: elasticsearch/client/__pycache__/rollup.cpython-38.pyc (deflated 68%)
#   adding: elasticsearch/client/__pycache__/tasks.cpython-38.pyc (deflated 61%)
#   adding: elasticsearch/client/__pycache__/nodes.cpython-38.pyc (deflated 67%)
#   adding: elasticsearch/client/__pycache__/utils.cpython-38.pyc (deflated 44%)
#   adding: elasticsearch/client/__pycache__/ssl.cpython-38.pyc (deflated 36%)
#   adding: elasticsearch/client/__pycache__/migration.cpython-38.pyc (deflated 38%)
#   adding: elasticsearch/client/__pycache__/security.cpython-38.pyc (deflated 81%)
#   adding: elasticsearch/client/__pycache__/searchable_snapshots.cpython-38.pyc (deflated 62%)
#   adding: elasticsearch/client/__pycache__/remote.cpython-38.pyc (deflated 35%)
#   adding: elasticsearch/client/__pycache__/license.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/client/__pycache__/sql.cpython-38.pyc (deflated 54%)
#   adding: elasticsearch/client/__pycache__/monitoring.cpython-38.pyc (deflated 42%)
#   adding: elasticsearch/client/__pycache__/slm.cpython-38.pyc (deflated 66%)
#   adding: elasticsearch/client/__pycache__/cat.cpython-38.pyc (deflated 84%)
#   adding: elasticsearch/client/__pycache__/ilm.cpython-38.pyc (deflated 67%)
#   adding: elasticsearch/client/__pycache__/autoscaling.cpython-38.pyc (deflated 64%)
#   adding: elasticsearch/client/__pycache__/dangling_indices.cpython-38.pyc (deflated 59%)
#   adding: elasticsearch/client/__pycache__/deprecation.cpython-38.pyc (deflated 36%)
#   adding: elasticsearch/client/__pycache__/ingest.cpython-38.pyc (deflated 60%)
#   adding: elasticsearch/client/__pycache__/cluster.cpython-38.pyc (deflated 73%)
#   adding: elasticsearch/client/__pycache__/ml.cpython-38.pyc (deflated 80%)
#   adding: elasticsearch/client/__pycache__/enrich.cpython-38.pyc (deflated 58%)
#   adding: elasticsearch/client/ml.pyi (deflated 95%)
#   adding: elasticsearch/client/utils.pyi (deflated 50%)
#   adding: elasticsearch/client/ml.py (deflated 88%)
#   adding: elasticsearch/client/ingest.pyi (deflated 81%)
#   adding: elasticsearch/client/data_frame.pyi (deflated 84%)
#   adding: elasticsearch/client/ccr.py (deflated 81%)
#   adding: elasticsearch/client/utils.py (deflated 62%)
#   adding: elasticsearch/client/cluster.py (deflated 80%)
#   adding: elasticsearch/client/data_frame.py (deflated 78%)
#   adding: elasticsearch/client/cluster.pyi (deflated 90%)
#   adding: elasticsearch/client/transform.py (deflated 79%)
#   adding: elasticsearch/client/watcher.pyi (deflated 88%)
#   adding: elasticsearch/client/indices.py (deflated 89%)
#   adding: elasticsearch/client/license.py (deflated 74%)
#   adding: elasticsearch/client/ccr.pyi (deflated 90%)
#   adding: elasticsearch/client/watcher.py (deflated 78%)
#   adding: elasticsearch/client/sql.py (deflated 65%)
#   adding: elasticsearch/client/ilm.py (deflated 78%)
#   adding: elasticsearch/client/nodes.py (deflated 73%)
#   adding: elasticsearch/client/monitoring.pyi (deflated 56%)
#   adding: elasticsearch/client/searchable_snapshots.py (deflated 70%)
#   adding: elasticsearch/client/ssl.py (deflated 46%)
#   adding: elasticsearch/client/remote.pyi (deflated 52%)
#   adding: elasticsearch/client/migration.py (deflated 48%)
#   adding: elasticsearch/client/enrich.pyi (deflated 80%)
#   adding: elasticsearch/client/autoscaling.py (deflated 73%)
#   adding: elasticsearch/client/tasks.pyi (deflated 75%)
#   adding: elasticsearch/client/dangling_indices.pyi (deflated 74%)
#   adding: elasticsearch/client/sql.pyi (deflated 72%)
#   adding: elasticsearch/client/transform.pyi (deflated 86%)
#   adding: elasticsearch/client/snapshot.py (deflated 84%)
#   adding: elasticsearch/client/snapshot.pyi (deflated 89%)
#   adding: elasticsearch/helpers/ (stored 0%)
#   adding: elasticsearch/helpers/test.pyi (deflated 49%)
#   adding: elasticsearch/helpers/__init__.pyi (deflated 53%)
#   adding: elasticsearch/helpers/actions.py (deflated 71%)
#   adding: elasticsearch/helpers/__init__.py (deflated 53%)
#   adding: elasticsearch/helpers/__pycache__/ (stored 0%)
#   adding: elasticsearch/helpers/__pycache__/test.cpython-38.pyc (deflated 42%)
#   adding: elasticsearch/helpers/__pycache__/__init__.cpython-38.pyc (deflated 35%)
#   adding: elasticsearch/helpers/__pycache__/errors.cpython-38.pyc (deflated 40%)
#   adding: elasticsearch/helpers/__pycache__/actions.cpython-38.pyc (deflated 56%)
#   adding: elasticsearch/helpers/test.py (deflated 55%)
#   adding: elasticsearch/helpers/actions.pyi (deflated 68%)
#   adding: elasticsearch/helpers/errors.pyi (deflated 46%)
#   adding: elasticsearch/helpers/errors.py (deflated 48%)
#   adding: elasticsearch/connection_pool.py (deflated 69%)
#   adding: requests-2.28.1.dist-info/ (stored 0%)
#   adding: requests-2.28.1.dist-info/RECORD (deflated 55%)
#   adding: requests-2.28.1.dist-info/LICENSE (deflated 65%)
#   adding: requests-2.28.1.dist-info/WHEEL (stored 0%)
#   adding: requests-2.28.1.dist-info/top_level.txt (stored 0%)
#   adding: requests-2.28.1.dist-info/REQUESTED (stored 0%)
#   adding: requests-2.28.1.dist-info/INSTALLER (stored 0%)
#   adding: requests-2.28.1.dist-info/METADATA (deflated 57%)
#   adding: app.py (deflated 67%)

# %%
# !unzip -l lambda.zip
# Out:
# Archive:  lambda.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#         0  09-29-2022 10:17   bin/
#       268  09-29-2022 10:17   bin/normalizer
#         0  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/
#      2550  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/RECORD
#      1070  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/LICENSE
#        92  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/WHEEL
#        76  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/entry_points.txt
#        19  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/top_level.txt
#         4  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/INSTALLER
#     11942  09-29-2022 10:17   charset_normalizer-2.1.1.dist-info/METADATA
#         0  09-29-2022 10:17   six-1.16.0.dist-info/
#       560  09-29-2022 10:17   six-1.16.0.dist-info/RECORD
#      1066  09-29-2022 10:17   six-1.16.0.dist-info/LICENSE
#       110  09-29-2022 10:17   six-1.16.0.dist-info/WHEEL
#         4  09-29-2022 10:17   six-1.16.0.dist-info/top_level.txt
#         4  09-29-2022 10:17   six-1.16.0.dist-info/INSTALLER
#      1795  09-29-2022 10:17   six-1.16.0.dist-info/METADATA
#         0  09-29-2022 10:17   urllib3-1.26.12.dist-info/
#      5747  09-29-2022 10:17   urllib3-1.26.12.dist-info/RECORD
#       110  09-29-2022 10:17   urllib3-1.26.12.dist-info/WHEEL
#         8  09-29-2022 10:17   urllib3-1.26.12.dist-info/top_level.txt
#      1115  09-29-2022 10:17   urllib3-1.26.12.dist-info/LICENSE.txt
#         4  09-29-2022 10:17   urllib3-1.26.12.dist-info/INSTALLER
#     47076  09-29-2022 10:17   urllib3-1.26.12.dist-info/METADATA
#         0  09-29-2022 10:17   idna/
#      1881  09-29-2022 10:17   idna/intranges.py
#        21  09-29-2022 10:17   idna/package_data.py
#       321  09-29-2022 10:17   idna/compat.py
#     44375  09-29-2022 10:17   idna/idnadata.py
#       849  09-29-2022 10:17   idna/__init__.py
#     12950  09-29-2022 10:17   idna/core.py
#         0  09-29-2022 10:17   idna/__pycache__/
#       924  09-29-2022 10:17   idna/__pycache__/__init__.cpython-38.pyc
#    185433  09-29-2022 10:17   idna/__pycache__/uts46data.cpython-38.pyc
#      2004  09-29-2022 10:17   idna/__pycache__/intranges.cpython-38.pyc
#       218  09-29-2022 10:17   idna/__pycache__/package_data.cpython-38.pyc
#      9913  09-29-2022 10:17   idna/__pycache__/core.cpython-38.pyc
#     23208  09-29-2022 10:17   idna/__pycache__/idnadata.cpython-38.pyc
#       773  09-29-2022 10:17   idna/__pycache__/compat.cpython-38.pyc
#      3091  09-29-2022 10:17   idna/__pycache__/codec.cpython-38.pyc
#         0  09-29-2022 10:17   idna/py.typed
#      3374  09-29-2022 10:17   idna/codec.py
#    206539  09-29-2022 10:17   idna/uts46data.py
#         0  09-29-2022 10:17   certifi-2022.9.24.dist-info/
#      1012  09-29-2022 10:17   certifi-2022.9.24.dist-info/RECORD
#      1052  09-29-2022 10:17   certifi-2022.9.24.dist-info/LICENSE
#        92  09-29-2022 10:17   certifi-2022.9.24.dist-info/WHEEL
#         8  09-29-2022 10:17   certifi-2022.9.24.dist-info/top_level.txt
#         4  09-29-2022 10:17   certifi-2022.9.24.dist-info/INSTALLER
#      2911  09-29-2022 10:17   certifi-2022.9.24.dist-info/METADATA
#         0  09-29-2022 10:17   __pycache__/
#     27493  09-29-2022 10:17   __pycache__/six.cpython-38.pyc
#         0  09-29-2022 10:17   idna-3.4.dist-info/
#      1523  09-29-2022 10:17   idna-3.4.dist-info/LICENSE.md
#      1370  09-29-2022 10:17   idna-3.4.dist-info/RECORD
#        81  09-29-2022 10:17   idna-3.4.dist-info/WHEEL
#         4  09-29-2022 10:17   idna-3.4.dist-info/INSTALLER
#      9830  09-29-2022 10:17   idna-3.4.dist-info/METADATA
#         0  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/
#     22229  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/RECORD
#     10143  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/LICENSE
#       136  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/AUTHORS
#       110  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/WHEEL
#        14  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/top_level.txt
#         0  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/REQUESTED
#         4  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/INSTALLER
#      8004  09-29-2022 10:17   elasticsearch-7.10.0.dist-info/METADATA
#         0  09-29-2022 10:17   charset_normalizer/
#     17642  09-29-2022 10:17   charset_normalizer/md.py
#        79  09-29-2022 10:17   charset_normalizer/version.py
#      3384  09-29-2022 10:17   charset_normalizer/legacy.py
#     13167  09-29-2022 10:17   charset_normalizer/models.py
#      1790  09-29-2022 10:17   charset_normalizer/__init__.py
#         0  09-29-2022 10:17   charset_normalizer/__pycache__/
#     11092  09-29-2022 10:17   charset_normalizer/__pycache__/api.cpython-38.pyc
#      1745  09-29-2022 10:17   charset_normalizer/__pycache__/__init__.cpython-38.pyc
#      3043  09-29-2022 10:17   charset_normalizer/__pycache__/legacy.cpython-38.pyc
#     14130  09-29-2022 10:17   charset_normalizer/__pycache__/constant.cpython-38.pyc
#      9155  09-29-2022 10:17   charset_normalizer/__pycache__/utils.cpython-38.pyc
#     13242  09-29-2022 10:17   charset_normalizer/__pycache__/models.cpython-38.pyc
#      8661  09-29-2022 10:17   charset_normalizer/__pycache__/cd.cpython-38.pyc
#       293  09-29-2022 10:17   charset_normalizer/__pycache__/version.cpython-38.pyc
#     14747  09-29-2022 10:17   charset_normalizer/__pycache__/md.cpython-38.pyc
#         0  09-29-2022 10:17   charset_normalizer/cli/
#         0  09-29-2022 10:17   charset_normalizer/cli/__init__.py
#         0  09-29-2022 10:17   charset_normalizer/cli/__pycache__/
#       213  09-29-2022 10:17   charset_normalizer/cli/__pycache__/__init__.cpython-38.pyc
#      6314  09-29-2022 10:17   charset_normalizer/cli/__pycache__/normalizer.cpython-38.pyc
#      9521  09-29-2022 10:17   charset_normalizer/cli/normalizer.py
#     19191  09-29-2022 10:17   charset_normalizer/api.py
#     11771  09-29-2022 10:17   charset_normalizer/utils.py
#         0  09-29-2022 10:17   charset_normalizer/py.typed
#     19157  09-29-2022 10:17   charset_normalizer/constant.py
#         0  09-29-2022 10:17   charset_normalizer/assets/
#     15222  09-29-2022 10:17   charset_normalizer/assets/__init__.py
#         0  09-29-2022 10:17   charset_normalizer/assets/__pycache__/
#      7843  09-29-2022 10:17   charset_normalizer/assets/__pycache__/__init__.cpython-38.pyc
#     10811  09-29-2022 10:17   charset_normalizer/cd.py
#         0  09-29-2022 10:17   requests/
#     18560  09-29-2022 10:17   requests/cookies.py
#     10187  09-29-2022 10:17   requests/auth.py
#     30180  09-29-2022 10:17   requests/sessions.py
#       733  09-29-2022 10:17   requests/hooks.py
#      1451  09-29-2022 10:17   requests/compat.py
#     35222  09-29-2022 10:17   requests/models.py
#       429  09-29-2022 10:17   requests/certs.py
#      4972  09-29-2022 10:17   requests/__init__.py
#      4235  09-29-2022 10:17   requests/status_codes.py
#       957  09-29-2022 10:17   requests/packages.py
#       440  09-29-2022 10:17   requests/__version__.py
#         0  09-29-2022 10:17   requests/__pycache__/
#      6702  09-29-2022 10:17   requests/__pycache__/api.cpython-38.pyc
#      3909  09-29-2022 10:17   requests/__pycache__/__init__.cpython-38.pyc
#     18831  09-29-2022 10:17   requests/__pycache__/cookies.cpython-38.pyc
#      8355  09-29-2022 10:17   requests/__pycache__/auth.cpython-38.pyc
#       999  09-29-2022 10:17   requests/__pycache__/hooks.cpython-38.pyc
#     24165  09-29-2022 10:17   requests/__pycache__/utils.cpython-38.pyc
#     16919  09-29-2022 10:17   requests/__pycache__/adapters.cpython-38.pyc
#       720  09-29-2022 10:17   requests/__pycache__/packages.cpython-38.pyc
#     24286  09-29-2022 10:17   requests/__pycache__/models.cpython-38.pyc
#      1531  09-29-2022 10:17   requests/__pycache__/compat.cpython-38.pyc
#      4458  09-29-2022 10:17   requests/__pycache__/structures.cpython-38.pyc
#       628  09-29-2022 10:17   requests/__pycache__/certs.cpython-38.pyc
#      6114  09-29-2022 10:17   requests/__pycache__/exceptions.cpython-38.pyc
#       562  09-29-2022 10:17   requests/__pycache__/__version__.cpython-38.pyc
#      4250  09-29-2022 10:17   requests/__pycache__/status_codes.cpython-38.pyc
#     19694  09-29-2022 10:17   requests/__pycache__/sessions.cpython-38.pyc
#      1593  09-29-2022 10:17   requests/__pycache__/_internal_utils.cpython-38.pyc
#      2854  09-29-2022 10:17   requests/__pycache__/help.cpython-38.pyc
#      6377  09-29-2022 10:17   requests/api.py
#      1397  09-29-2022 10:17   requests/_internal_utils.py
#     33228  09-29-2022 10:17   requests/utils.py
#      3811  09-29-2022 10:17   requests/exceptions.py
#      2912  09-29-2022 10:17   requests/structures.py
#      3875  09-29-2022 10:17   requests/help.py
#     21287  09-29-2022 10:17   requests/adapters.py
#         0  09-29-2022 10:17   certifi/
#        94  09-29-2022 10:17   certifi/__init__.py
#      4219  09-29-2022 10:17   certifi/core.py
#         0  09-29-2022 10:17   certifi/__pycache__/
#       311  09-29-2022 10:17   certifi/__pycache__/__init__.cpython-38.pyc
#      1906  09-29-2022 10:17   certifi/__pycache__/core.cpython-38.pyc
#       447  09-29-2022 10:17   certifi/__pycache__/__main__.cpython-38.pyc
#         0  09-29-2022 10:17   certifi/py.typed
#    286370  09-29-2022 10:17   certifi/cacert.pem
#       243  09-29-2022 10:17   certifi/__main__.py
#         0  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/
#      1231  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/RECORD
#      1082  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/LICENSE
#       110  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/WHEEL
#        18  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/top_level.txt
#         0  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/REQUESTED
#         4  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/INSTALLER
#     17578  09-29-2022 10:17   requests_aws4auth-1.1.2.dist-info/METADATA
#         0  09-29-2022 10:17   requests_aws4auth/
#      8452  09-29-2022 10:17   requests_aws4auth/__init__.py
#         0  09-29-2022 10:17   requests_aws4auth/__pycache__/
#      8635  09-29-2022 10:17   requests_aws4auth/__pycache__/__init__.cpython-38.pyc
#     29194  09-29-2022 10:17   requests_aws4auth/__pycache__/aws4auth.cpython-38.pyc
#      5581  09-29-2022 10:17   requests_aws4auth/__pycache__/aws4signingkey.cpython-38.pyc
#       913  09-29-2022 10:17   requests_aws4auth/__pycache__/exceptions.cpython-38.pyc
#     33951  09-29-2022 10:17   requests_aws4auth/aws4auth.py
#      5437  09-29-2022 10:17   requests_aws4auth/aws4signingkey.py
#       408  09-29-2022 10:17   requests_aws4auth/exceptions.py
#     34549  09-29-2022 10:17   six.py
#         0  09-29-2022 10:17   urllib3/
#      2440  09-29-2022 10:17   urllib3/filepost.py
#      8579  09-29-2022 10:17   urllib3/fields.py
#         0  09-29-2022 10:17   urllib3/util/
#       498  09-29-2022 10:17   urllib3/util/queue.py
#      6895  09-29-2022 10:17   urllib3/util/ssltransport.py
#      1605  09-29-2022 10:17   urllib3/util/proxy.py
#      5403  09-29-2022 10:17   urllib3/util/wait.py
#      4225  09-29-2022 10:17   urllib3/util/request.py
#     10003  09-29-2022 10:17   urllib3/util/timeout.py
#      1155  09-29-2022 10:17   urllib3/util/__init__.py
#      3510  09-29-2022 10:17   urllib3/util/response.py
#     17165  09-29-2022 10:17   urllib3/util/ssl_.py
#         0  09-29-2022 10:17   urllib3/util/__pycache__/
#      1116  09-29-2022 10:17   urllib3/util/__pycache__/__init__.cpython-38.pyc
#      1071  09-29-2022 10:17   urllib3/util/__pycache__/queue.cpython-38.pyc
#     11391  09-29-2022 10:17   urllib3/util/__pycache__/ssl_.cpython-38.pyc
#     16279  09-29-2022 10:17   urllib3/util/__pycache__/retry.cpython-38.pyc
#      3118  09-29-2022 10:17   urllib3/util/__pycache__/wait.cpython-38.pyc
#      7450  09-29-2022 10:17   urllib3/util/__pycache__/ssltransport.cpython-38.pyc
#      3276  09-29-2022 10:17   urllib3/util/__pycache__/ssl_match_hostname.cpython-38.pyc
#      3454  09-29-2022 10:17   urllib3/util/__pycache__/connection.cpython-38.pyc
#     10774  09-29-2022 10:17   urllib3/util/__pycache__/url.cpython-38.pyc
#      3517  09-29-2022 10:17   urllib3/util/__pycache__/request.cpython-38.pyc
#      1360  09-29-2022 10:17   urllib3/util/__pycache__/proxy.cpython-38.pyc
#      2364  09-29-2022 10:17   urllib3/util/__pycache__/response.cpython-38.pyc
#      8958  09-29-2022 10:17   urllib3/util/__pycache__/timeout.cpython-38.pyc
#     22001  09-29-2022 10:17   urllib3/util/retry.py
#     14270  09-29-2022 10:17   urllib3/util/url.py
#      4901  09-29-2022 10:17   urllib3/util/connection.py
#      5758  09-29-2022 10:17   urllib3/util/ssl_match_hostname.py
#        64  09-29-2022 10:17   urllib3/_version.py
#      5985  09-29-2022 10:17   urllib3/request.py
#      3333  09-29-2022 10:17   urllib3/__init__.py
#     19786  09-29-2022 10:17   urllib3/poolmanager.py
#     30229  09-29-2022 10:17   urllib3/response.py
#         0  09-29-2022 10:17   urllib3/__pycache__/
#      2516  09-29-2022 10:17   urllib3/__pycache__/__init__.cpython-38.pyc
#      8190  09-29-2022 10:17   urllib3/__pycache__/fields.cpython-38.pyc
#     10709  09-29-2022 10:17   urllib3/__pycache__/_collections.cpython-38.pyc
#     25392  09-29-2022 10:17   urllib3/__pycache__/connectionpool.cpython-38.pyc
#     13698  09-29-2022 10:17   urllib3/__pycache__/connection.cpython-38.pyc
#      2777  09-29-2022 10:17   urllib3/__pycache__/filepost.cpython-38.pyc
#      5633  09-29-2022 10:17   urllib3/__pycache__/request.cpython-38.pyc
#       221  09-29-2022 10:17   urllib3/__pycache__/_version.cpython-38.pyc
#     11653  09-29-2022 10:17   urllib3/__pycache__/exceptions.cpython-38.pyc
#     21994  09-29-2022 10:17   urllib3/__pycache__/response.cpython-38.pyc
#     15152  09-29-2022 10:17   urllib3/__pycache__/poolmanager.cpython-38.pyc
#         0  09-29-2022 10:17   urllib3/contrib/
#     34416  09-29-2022 10:17   urllib3/contrib/securetransport.py
#         0  09-29-2022 10:17   urllib3/contrib/__init__.py
#         0  09-29-2022 10:17   urllib3/contrib/__pycache__/
#     15857  09-29-2022 10:17   urllib3/contrib/__pycache__/pyopenssl.cpython-38.pyc
#       206  09-29-2022 10:17   urllib3/contrib/__pycache__/__init__.cpython-38.pyc
#      1430  09-29-2022 10:17   urllib3/contrib/__pycache__/_appengine_environ.cpython-38.pyc
#      5644  09-29-2022 10:17   urllib3/contrib/__pycache__/socks.cpython-38.pyc
#     21628  09-29-2022 10:17   urllib3/contrib/__pycache__/securetransport.cpython-38.pyc
#      8255  09-29-2022 10:17   urllib3/contrib/__pycache__/appengine.cpython-38.pyc
#      3649  09-29-2022 10:17   urllib3/contrib/__pycache__/ntlmpool.cpython-38.pyc
#      7097  09-29-2022 10:17   urllib3/contrib/socks.py
#       957  09-29-2022 10:17   urllib3/contrib/_appengine_environ.py
#     17156  09-29-2022 10:17   urllib3/contrib/pyopenssl.py
#     11010  09-29-2022 10:17   urllib3/contrib/appengine.py
#         0  09-29-2022 10:17   urllib3/contrib/_securetransport/
#         0  09-29-2022 10:17   urllib3/contrib/_securetransport/__init__.py
#         0  09-29-2022 10:17   urllib3/contrib/_securetransport/__pycache__/
#       223  09-29-2022 10:17   urllib3/contrib/_securetransport/__pycache__/__init__.cpython-38.pyc
#     10741  09-29-2022 10:17   urllib3/contrib/_securetransport/__pycache__/bindings.cpython-38.pyc
#      9115  09-29-2022 10:17   urllib3/contrib/_securetransport/__pycache__/low_level.cpython-38.pyc
#     13922  09-29-2022 10:17   urllib3/contrib/_securetransport/low_level.py
#     17632  09-29-2022 10:17   urllib3/contrib/_securetransport/bindings.py
#      4538  09-29-2022 10:17   urllib3/contrib/ntlmpool.py
#     20070  09-29-2022 10:17   urllib3/connection.py
#     10811  09-29-2022 10:17   urllib3/_collections.py
#         0  09-29-2022 10:17   urllib3/packages/
#         0  09-29-2022 10:17   urllib3/packages/__init__.py
#         0  09-29-2022 10:17   urllib3/packages/__pycache__/
#       207  09-29-2022 10:17   urllib3/packages/__pycache__/__init__.cpython-38.pyc
#     27602  09-29-2022 10:17   urllib3/packages/__pycache__/six.cpython-38.pyc
#         0  09-29-2022 10:17   urllib3/packages/backports/
#         0  09-29-2022 10:17   urllib3/packages/backports/__init__.py
#         0  09-29-2022 10:17   urllib3/packages/backports/__pycache__/
#       217  09-29-2022 10:17   urllib3/packages/backports/__pycache__/__init__.cpython-38.pyc
#      1321  09-29-2022 10:17   urllib3/packages/backports/__pycache__/makefile.cpython-38.pyc
#      1417  09-29-2022 10:17   urllib3/packages/backports/makefile.py
#     34665  09-29-2022 10:17   urllib3/packages/six.py
#      8217  09-29-2022 10:17   urllib3/exceptions.py
#     39093  09-29-2022 10:17   urllib3/connectionpool.py
#         0  09-29-2022 10:17   elasticsearch/
#      3267  09-29-2022 10:17   elasticsearch/transport.pyi
#      1460  09-29-2022 10:17   elasticsearch/compat.py
#         0  09-29-2022 10:17   elasticsearch/connection/
#      1051  09-29-2022 10:17   elasticsearch/connection/pooling.pyi
#      3300  09-29-2022 10:17   elasticsearch/connection/base.pyi
#      2001  09-29-2022 10:17   elasticsearch/connection/http_urllib3.pyi
#      1035  09-29-2022 10:17   elasticsearch/connection/__init__.pyi
#      1555  09-29-2022 10:17   elasticsearch/connection/http_requests.pyi
#      1766  09-29-2022 10:17   elasticsearch/connection/pooling.py
#      1053  09-29-2022 10:17   elasticsearch/connection/__init__.py
#         0  09-29-2022 10:17   elasticsearch/connection/__pycache__/
#       452  09-29-2022 10:17   elasticsearch/connection/__pycache__/__init__.cpython-38.pyc
#      5038  09-29-2022 10:17   elasticsearch/connection/__pycache__/http_requests.cpython-38.pyc
#      7889  09-29-2022 10:17   elasticsearch/connection/__pycache__/base.cpython-38.pyc
#      1742  09-29-2022 10:17   elasticsearch/connection/__pycache__/pooling.cpython-38.pyc
#      6754  09-29-2022 10:17   elasticsearch/connection/__pycache__/http_urllib3.cpython-38.pyc
#     10466  09-29-2022 10:17   elasticsearch/connection/http_urllib3.py
#     11598  09-29-2022 10:17   elasticsearch/connection/base.py
#      7660  09-29-2022 10:17   elasticsearch/connection/http_requests.py
#      2331  09-29-2022 10:17   elasticsearch/__init__.pyi
#       814  09-29-2022 10:17   elasticsearch/_version.py
#     17810  09-29-2022 10:17   elasticsearch/transport.py
#         0  09-29-2022 10:17   elasticsearch/_async/
#      3150  09-29-2022 10:17   elasticsearch/_async/transport.pyi
#      1432  09-29-2022 10:17   elasticsearch/_async/compat.py
#     14715  09-29-2022 10:17   elasticsearch/_async/transport.py
#      2327  09-29-2022 10:17   elasticsearch/_async/http_aiohttp.pyi
#      3250  09-29-2022 10:17   elasticsearch/_async/helpers.pyi
#       787  09-29-2022 10:17   elasticsearch/_async/__init__.py
#       861  09-29-2022 10:17   elasticsearch/_async/compat.pyi
#         0  09-29-2022 10:17   elasticsearch/_async/__pycache__/
#       211  09-29-2022 10:17   elasticsearch/_async/__pycache__/__init__.cpython-38.pyc
#     12490  09-29-2022 10:17   elasticsearch/_async/__pycache__/helpers.cpython-38.pyc
#     10660  09-29-2022 10:17   elasticsearch/_async/__pycache__/transport.cpython-38.pyc
#       418  09-29-2022 10:17   elasticsearch/_async/__pycache__/_extra_imports.cpython-38.pyc
#       548  09-29-2022 10:17   elasticsearch/_async/__pycache__/compat.cpython-38.pyc
#      8674  09-29-2022 10:17   elasticsearch/_async/__pycache__/http_aiohttp.cpython-38.pyc
#     13245  09-29-2022 10:17   elasticsearch/_async/http_aiohttp.py
#      1725  09-29-2022 10:17   elasticsearch/_async/_extra_imports.py
#     16132  09-29-2022 10:17   elasticsearch/_async/helpers.py
#         0  09-29-2022 10:17   elasticsearch/_async/client/
#      3611  09-29-2022 10:17   elasticsearch/_async/client/searchable_snapshots.pyi
#      2323  09-29-2022 10:17   elasticsearch/_async/client/xpack.pyi
#      7941  09-29-2022 10:17   elasticsearch/_async/client/rollup.py
#      4338  09-29-2022 10:17   elasticsearch/_async/client/ingest.py
#      5192  09-29-2022 10:17   elasticsearch/_async/client/license.pyi
#      4653  09-29-2022 10:17   elasticsearch/_async/client/async_search.pyi
#      1497  09-29-2022 10:17   elasticsearch/_async/client/ssl.pyi
#      4522  09-29-2022 10:17   elasticsearch/_async/client/tasks.py
#      5812  09-29-2022 10:17   elasticsearch/_async/client/slm.py
#     21761  09-29-2022 10:17   elasticsearch/_async/client/cat.pyi
#      6920  09-29-2022 10:17   elasticsearch/_async/client/ilm.pyi
#     41933  09-29-2022 10:17   elasticsearch/_async/client/__init__.pyi
#      1664  09-29-2022 10:17   elasticsearch/_async/client/graph.pyi
#      3994  09-29-2022 10:17   elasticsearch/_async/client/enrich.py
#      4243  09-29-2022 10:17   elasticsearch/_async/client/eql.py
#      1336  09-29-2022 10:17   elasticsearch/_async/client/deprecation.py
#      1202  09-29-2022 10:17   elasticsearch/_async/client/remote.py
#      3122  09-29-2022 10:17   elasticsearch/_async/client/dangling_indices.py
#      2934  09-29-2022 10:17   elasticsearch/_async/client/eql.pyi
#     33429  09-29-2022 10:17   elasticsearch/_async/client/cat.py
#      4879  09-29-2022 10:17   elasticsearch/_async/client/nodes.pyi
#      2220  09-29-2022 10:17   elasticsearch/_async/client/monitoring.py
#      9624  09-29-2022 10:17   elasticsearch/_async/client/async_search.py
#      3333  09-29-2022 10:17   elasticsearch/_async/client/autoscaling.pyi
#      1539  09-29-2022 10:17   elasticsearch/_async/client/migration.pyi
#      2016  09-29-2022 10:17   elasticsearch/_async/client/graph.py
#     23834  09-29-2022 10:17   elasticsearch/_async/client/security.py
#      2152  09-29-2022 10:17   elasticsearch/_async/client/xpack.py
#     43090  09-29-2022 10:17   elasticsearch/_async/client/indices.pyi
#      1534  09-29-2022 10:17   elasticsearch/_async/client/deprecation.pyi
#      6192  09-29-2022 10:17   elasticsearch/_async/client/slm.pyi
#     18985  09-29-2022 10:17   elasticsearch/_async/client/security.pyi
#     91570  09-29-2022 10:17   elasticsearch/_async/client/__init__.py
#      5911  09-29-2022 10:17   elasticsearch/_async/client/rollup.pyi
#         0  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/
#      1523  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/graph.cpython-38.pyc
#      6911  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/transform.cpython-38.pyc
#     79143  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/__init__.cpython-38.pyc
#      1751  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/xpack.cpython-38.pyc
#      8614  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/snapshot.cpython-38.pyc
#      8759  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/ccr.cpython-38.pyc
#      5929  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/watcher.cpython-38.pyc
#      4716  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/data_frame.cpython-38.pyc
#      3493  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/eql.cpython-38.pyc
#      8596  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/async_search.cpython-38.pyc
#     60993  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/indices.cpython-38.pyc
#      6705  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/rollup.cpython-38.pyc
#      3816  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/tasks.cpython-38.pyc
#      6933  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/nodes.cpython-38.pyc
#       401  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/utils.cpython-38.pyc
#       919  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/ssl.cpython-38.pyc
#      1099  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/migration.cpython-38.pyc
#     19731  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/security.cpython-38.pyc
#      4409  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/searchable_snapshots.cpython-38.pyc
#       793  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/remote.cpython-38.pyc
#      3911  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/license.cpython-38.pyc
#      2059  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/sql.cpython-38.pyc
#      1730  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/monitoring.cpython-38.pyc
#      4742  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/slm.cpython-38.pyc
#     30230  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/cat.cpython-38.pyc
#      5773  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/ilm.cpython-38.pyc
#      3367  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/autoscaling.cpython-38.pyc
#      2515  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/dangling_indices.cpython-38.pyc
#       897  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/deprecation.cpython-38.pyc
#      3545  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/ingest.cpython-38.pyc
#     15191  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/cluster.cpython-38.pyc
#     50923  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/ml.cpython-38.pyc
#      3166  09-29-2022 10:17   elasticsearch/_async/client/__pycache__/enrich.cpython-38.pyc
#     43374  09-29-2022 10:17   elasticsearch/_async/client/ml.pyi
#      1282  09-29-2022 10:17   elasticsearch/_async/client/utils.pyi
#     64570  09-29-2022 10:17   elasticsearch/_async/client/ml.py
#      4164  09-29-2022 10:17   elasticsearch/_async/client/ingest.pyi
#      5448  09-29-2022 10:17   elasticsearch/_async/client/data_frame.pyi
#     10980  09-29-2022 10:17   elasticsearch/_async/client/ccr.py
#       953  09-29-2022 10:17   elasticsearch/_async/client/utils.py
#     17013  09-29-2022 10:17   elasticsearch/_async/client/cluster.py
#      6092  09-29-2022 10:17   elasticsearch/_async/client/data_frame.py
#     12096  09-29-2022 10:17   elasticsearch/_async/client/cluster.pyi
#      8910  09-29-2022 10:17   elasticsearch/_async/client/transform.py
#      7142  09-29-2022 10:17   elasticsearch/_async/client/watcher.pyi
#     71158  09-29-2022 10:17   elasticsearch/_async/client/indices.py
#      4581  09-29-2022 10:17   elasticsearch/_async/client/license.py
#      8770  09-29-2022 10:17   elasticsearch/_async/client/ccr.pyi
#      7371  09-29-2022 10:17   elasticsearch/_async/client/watcher.py
#      2760  09-29-2022 10:17   elasticsearch/_async/client/sql.py
#      7080  09-29-2022 10:17   elasticsearch/_async/client/ilm.py
#      7961  09-29-2022 10:17   elasticsearch/_async/client/nodes.py
#      1682  09-29-2022 10:17   elasticsearch/_async/client/monitoring.pyi
#      5143  09-29-2022 10:17   elasticsearch/_async/client/searchable_snapshots.py
#      1326  09-29-2022 10:17   elasticsearch/_async/client/ssl.py
#      1378  09-29-2022 10:17   elasticsearch/_async/client/remote.pyi
#      1540  09-29-2022 10:17   elasticsearch/_async/client/migration.py
#      3929  09-29-2022 10:17   elasticsearch/_async/client/enrich.pyi
#      4078  09-29-2022 10:17   elasticsearch/_async/client/autoscaling.py
#      3232  09-29-2022 10:17   elasticsearch/_async/client/tasks.pyi
#      2984  09-29-2022 10:17   elasticsearch/_async/client/dangling_indices.pyi
#      2682  09-29-2022 10:17   elasticsearch/_async/client/sql.pyi
#      6394  09-29-2022 10:17   elasticsearch/_async/client/transform.pyi
#     11196  09-29-2022 10:17   elasticsearch/_async/client/snapshot.py
#      8731  09-29-2022 10:17   elasticsearch/_async/client/snapshot.pyi
#      1754  09-29-2022 10:17   elasticsearch/exceptions.pyi
#      3018  09-29-2022 10:17   elasticsearch/__init__.py
#      1409  09-29-2022 10:17   elasticsearch/compat.pyi
#         0  09-29-2022 10:17   elasticsearch/__pycache__/
#      2099  09-29-2022 10:17   elasticsearch/__pycache__/__init__.cpython-38.pyc
#     12234  09-29-2022 10:17   elasticsearch/__pycache__/transport.cpython-38.pyc
#       829  09-29-2022 10:17   elasticsearch/__pycache__/compat.cpython-38.pyc
#     10299  09-29-2022 10:17   elasticsearch/__pycache__/connection_pool.cpython-38.pyc
#       229  09-29-2022 10:17   elasticsearch/__pycache__/_version.cpython-38.pyc
#      3966  09-29-2022 10:17   elasticsearch/__pycache__/serializer.cpython-38.pyc
#      4969  09-29-2022 10:17   elasticsearch/__pycache__/exceptions.cpython-38.pyc
#         0  09-29-2022 10:17   elasticsearch/py.typed
#      1548  09-29-2022 10:17   elasticsearch/serializer.pyi
#      4588  09-29-2022 10:17   elasticsearch/serializer.py
#      4893  09-29-2022 10:17   elasticsearch/exceptions.py
#      2932  09-29-2022 10:17   elasticsearch/connection_pool.pyi
#         0  09-29-2022 10:17   elasticsearch/client/
#      3587  09-29-2022 10:17   elasticsearch/client/searchable_snapshots.pyi
#      2311  09-29-2022 10:17   elasticsearch/client/xpack.pyi
#      7831  09-29-2022 10:17   elasticsearch/client/rollup.py
#      4278  09-29-2022 10:17   elasticsearch/client/ingest.py
#      5150  09-29-2022 10:17   elasticsearch/client/license.pyi
#      4635  09-29-2022 10:17   elasticsearch/client/async_search.pyi
#      1491  09-29-2022 10:17   elasticsearch/client/ssl.pyi
#      4486  09-29-2022 10:17   elasticsearch/client/tasks.py
#      5704  09-29-2022 10:17   elasticsearch/client/slm.py
#     21611  09-29-2022 10:17   elasticsearch/client/cat.pyi
#      6860  09-29-2022 10:17   elasticsearch/client/ilm.pyi
#     41624  09-29-2022 10:17   elasticsearch/client/__init__.pyi
#      1658  09-29-2022 10:17   elasticsearch/client/graph.pyi
#      3934  09-29-2022 10:17   elasticsearch/client/enrich.py
#      4207  09-29-2022 10:17   elasticsearch/client/eql.py
#      1324  09-29-2022 10:17   elasticsearch/client/deprecation.py
#      1190  09-29-2022 10:17   elasticsearch/client/remote.py
#      3086  09-29-2022 10:17   elasticsearch/client/dangling_indices.py
#      2916  09-29-2022 10:17   elasticsearch/client/eql.pyi
#     33129  09-29-2022 10:17   elasticsearch/client/cat.py
#      4849  09-29-2022 10:17   elasticsearch/client/nodes.pyi
#      2208  09-29-2022 10:17   elasticsearch/client/monitoring.py
#      9588  09-29-2022 10:17   elasticsearch/client/async_search.py
#      3309  09-29-2022 10:17   elasticsearch/client/autoscaling.pyi
#      1533  09-29-2022 10:17   elasticsearch/client/migration.pyi
#      2004  09-29-2022 10:17   elasticsearch/client/graph.py
#     23472  09-29-2022 10:17   elasticsearch/client/security.py
#      2128  09-29-2022 10:17   elasticsearch/client/xpack.py
#     42772  09-29-2022 10:17   elasticsearch/client/indices.pyi
#      1528  09-29-2022 10:17   elasticsearch/client/deprecation.pyi
#      6138  09-29-2022 10:17   elasticsearch/client/slm.pyi
#     18811  09-29-2022 10:17   elasticsearch/client/security.pyi
#     90948  09-29-2022 10:17   elasticsearch/client/__init__.py
#      5863  09-29-2022 10:17   elasticsearch/client/rollup.pyi
#         0  09-29-2022 10:17   elasticsearch/client/__pycache__/
#      1509  09-29-2022 10:17   elasticsearch/client/__pycache__/graph.cpython-38.pyc
#      6848  09-29-2022 10:17   elasticsearch/client/__pycache__/transform.cpython-38.pyc
#     78551  09-29-2022 10:17   elasticsearch/client/__pycache__/__init__.cpython-38.pyc
#      1730  09-29-2022 10:17   elasticsearch/client/__pycache__/xpack.cpython-38.pyc
#      8530  09-29-2022 10:17   elasticsearch/client/__pycache__/snapshot.cpython-38.pyc
#      8661  09-29-2022 10:17   elasticsearch/client/__pycache__/ccr.cpython-38.pyc
#      5852  09-29-2022 10:17   elasticsearch/client/__pycache__/watcher.cpython-38.pyc
#      4646  09-29-2022 10:17   elasticsearch/client/__pycache__/data_frame.cpython-38.pyc
#      3465  09-29-2022 10:17   elasticsearch/client/__pycache__/eql.cpython-38.pyc
#      8568  09-29-2022 10:17   elasticsearch/client/__pycache__/async_search.cpython-38.pyc
#     60599  09-29-2022 10:17   elasticsearch/client/__pycache__/indices.cpython-38.pyc
#      6636  09-29-2022 10:17   elasticsearch/client/__pycache__/rollup.cpython-38.pyc
#      3788  09-29-2022 10:17   elasticsearch/client/__pycache__/tasks.cpython-38.pyc
#      6891  09-29-2022 10:17   elasticsearch/client/__pycache__/nodes.cpython-38.pyc
#      4457  09-29-2022 10:17   elasticsearch/client/__pycache__/utils.cpython-38.pyc
#       905  09-29-2022 10:17   elasticsearch/client/__pycache__/ssl.cpython-38.pyc
#      1085  09-29-2022 10:17   elasticsearch/client/__pycache__/migration.cpython-38.pyc
#     19513  09-29-2022 10:17   elasticsearch/client/__pycache__/security.cpython-38.pyc
#      4374  09-29-2022 10:17   elasticsearch/client/__pycache__/searchable_snapshots.cpython-38.pyc
#       779  09-29-2022 10:17   elasticsearch/client/__pycache__/remote.cpython-38.pyc
#      3855  09-29-2022 10:17   elasticsearch/client/__pycache__/license.cpython-38.pyc
#      2031  09-29-2022 10:17   elasticsearch/client/__pycache__/sql.cpython-38.pyc
#      1716  09-29-2022 10:17   elasticsearch/client/__pycache__/monitoring.cpython-38.pyc
#      4672  09-29-2022 10:17   elasticsearch/client/__pycache__/slm.cpython-38.pyc
#     30048  09-29-2022 10:17   elasticsearch/client/__pycache__/cat.cpython-38.pyc
#      5696  09-29-2022 10:17   elasticsearch/client/__pycache__/ilm.cpython-38.pyc
#      3332  09-29-2022 10:17   elasticsearch/client/__pycache__/autoscaling.cpython-38.pyc
#      2487  09-29-2022 10:17   elasticsearch/client/__pycache__/dangling_indices.cpython-38.pyc
#       883  09-29-2022 10:17   elasticsearch/client/__pycache__/deprecation.cpython-38.pyc
#      3503  09-29-2022 10:17   elasticsearch/client/__pycache__/ingest.cpython-38.pyc
#     15079  09-29-2022 10:17   elasticsearch/client/__pycache__/cluster.cpython-38.pyc
#     50452  09-29-2022 10:17   elasticsearch/client/__pycache__/ml.cpython-38.pyc
#      3124  09-29-2022 10:17   elasticsearch/client/__pycache__/enrich.cpython-38.pyc
#     43014  09-29-2022 10:17   elasticsearch/client/ml.pyi
#      1715  09-29-2022 10:17   elasticsearch/client/utils.pyi
#     63752  09-29-2022 10:17   elasticsearch/client/ml.py
#      4134  09-29-2022 10:17   elasticsearch/client/ingest.pyi
#      5406  09-29-2022 10:17   elasticsearch/client/data_frame.pyi
#     10824  09-29-2022 10:17   elasticsearch/client/ccr.py
#      5685  09-29-2022 10:17   elasticsearch/client/utils.py
#     16833  09-29-2022 10:17   elasticsearch/client/cluster.py
#      5966  09-29-2022 10:17   elasticsearch/client/data_frame.py
#     12006  09-29-2022 10:17   elasticsearch/client/cluster.pyi
#      8814  09-29-2022 10:17   elasticsearch/client/transform.py
#      7082  09-29-2022 10:17   elasticsearch/client/watcher.pyi
#     70494  09-29-2022 10:17   elasticsearch/client/indices.py
#      4497  09-29-2022 10:17   elasticsearch/client/license.py
#      8692  09-29-2022 10:17   elasticsearch/client/ccr.pyi
#      7251  09-29-2022 10:17   elasticsearch/client/watcher.py
#      2724  09-29-2022 10:17   elasticsearch/client/sql.py
#      6960  09-29-2022 10:17   elasticsearch/client/ilm.py
#      7901  09-29-2022 10:17   elasticsearch/client/nodes.py
#      1676  09-29-2022 10:17   elasticsearch/client/monitoring.pyi
#      5095  09-29-2022 10:17   elasticsearch/client/searchable_snapshots.py
#      1314  09-29-2022 10:17   elasticsearch/client/ssl.py
#      1372  09-29-2022 10:17   elasticsearch/client/remote.pyi
#      1528  09-29-2022 10:17   elasticsearch/client/migration.py
#      3899  09-29-2022 10:17   elasticsearch/client/enrich.pyi
#      4030  09-29-2022 10:17   elasticsearch/client/autoscaling.py
#      3214  09-29-2022 10:17   elasticsearch/client/tasks.pyi
#      2966  09-29-2022 10:17   elasticsearch/client/dangling_indices.pyi
#      2664  09-29-2022 10:17   elasticsearch/client/sql.pyi
#      6346  09-29-2022 10:17   elasticsearch/client/transform.pyi
#     11064  09-29-2022 10:17   elasticsearch/client/snapshot.py
#      8665  09-29-2022 10:17   elasticsearch/client/snapshot.pyi
#         0  09-29-2022 10:17   elasticsearch/helpers/
#      1280  09-29-2022 10:17   elasticsearch/helpers/test.pyi
#      1515  09-29-2022 10:17   elasticsearch/helpers/__init__.pyi
#     22543  09-29-2022 10:17   elasticsearch/helpers/actions.py
#      1591  09-29-2022 10:17   elasticsearch/helpers/__init__.py
#         0  09-29-2022 10:17   elasticsearch/helpers/__pycache__/
#      2556  09-29-2022 10:17   elasticsearch/helpers/__pycache__/test.cpython-38.pyc
#       897  09-29-2022 10:17   elasticsearch/helpers/__pycache__/__init__.cpython-38.pyc
#       985  09-29-2022 10:17   elasticsearch/helpers/__pycache__/errors.cpython-38.pyc
#     16238  09-29-2022 10:17   elasticsearch/helpers/__pycache__/actions.cpython-38.pyc
#      2772  09-29-2022 10:17   elasticsearch/helpers/test.py
#      3365  09-29-2022 10:17   elasticsearch/helpers/actions.pyi
#      1105  09-29-2022 10:17   elasticsearch/helpers/errors.pyi
#      1216  09-29-2022 10:17   elasticsearch/helpers/errors.py
#     11505  09-29-2022 10:17   elasticsearch/connection_pool.py
#         0  09-29-2022 10:17   requests-2.28.1.dist-info/
#      2833  09-29-2022 10:17   requests-2.28.1.dist-info/RECORD
#     10142  09-29-2022 10:17   requests-2.28.1.dist-info/LICENSE
#        92  09-29-2022 10:17   requests-2.28.1.dist-info/WHEEL
#         9  09-29-2022 10:17   requests-2.28.1.dist-info/top_level.txt
#         0  09-29-2022 10:17   requests-2.28.1.dist-info/REQUESTED
#         4  09-29-2022 10:17   requests-2.28.1.dist-info/INSTALLER
#      4641  09-29-2022 10:17   requests-2.28.1.dist-info/METADATA
#      3754  09-09-2022 14:21   app.py
# ---------                     -------
#   4822324                     536 files

# %%
# %cd /home/ec2-user/SageMaker/semantic-search
# Out:
# [Errno 2] No such file or directory: '/home/ec2-user/SageMaker/semantic-search'
# /Users/lijianwe/Documents/AWS/OpenSearch/ML/semantic-search/code/semantic-search/backend/lambda

# %%
s3_resource.Object(bucket, 'lambda/lambda.zip').upload_file('./lambda/lambda.zip',ExtraArgs={'ACL':'public-read'})
#lambda_zip_url = f'https://{bucket}.s3.amazonaws.com/lambda/lambda.zip'
lambda_zip_url = f's3://{bucket}/lambda/lambda.zip'
print("lambada zip file url: " + lambda_zip_url)
# Out:
# lambada zip file url: s3://static-cloudformation-semantic-s-s3buckettraining-zx4sh9dbq4sd/lambda/lambda.zip

# %% [markdown]
# ### Disable S3 "Block all public access"
#
# Go to S3 Console, click "Block Public Access settings for this account" make sure "Block all public access" is off.

# %%
s3_resource.Object(bucket, 'backend/template.yaml').upload_file('./backend/template.yaml', ExtraArgs={'ACL':'public-read'})


sam_template_url = f'https://{bucket}.s3.amazonaws.com/backend/template.yaml'
print("cloudformation template url:" + sam_template_url)


# Generate the CloudFormation Quick Create Link

print("Click the URL below to create the backend API for NLU search:\n")
print((
    'https://console.aws.amazon.com/cloudformation/home?region=us-east-1#/stacks/create/review'
    f'?templateURL={sam_template_url}'
    '&stackName=semantic-search-api'
    f'&param_BucketName={outputs["s3BucketTraining"]}'
    f'&param_DomainName={outputs["osDomainName"]}'
    f'&param_ElasticSearchURL={outputs["DomainEndpoint"]}'
    f'&param_SagemakerEndpoint={predictor.endpoint}'
    f'&param_LambdaZipFile={lambda_zip_url}'
))
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# cloudformation template url:https://static-cloudformation-semantic-s-s3buckettraining-zx4sh9dbq4sd.s3.amazonaws.com/backend/template.yaml
# Click the URL below to create the backend API for NLU search:
#
# https://console.aws.amazon.com/cloudformation/home?region=us-east-1#/stacks/create/review?templateURL=https://static-cloudformation-semantic-s-s3buckettraining-zx4sh9dbq4sd.s3.amazonaws.com/backend/template.yaml&stackName=semantic-search-api&param_BucketName=static-cloudformation-semantic-s-s3buckettraining-zx4sh9dbq4sd&param_DomainName=opensearchservi-mgtbvar5tkom&param_ElasticSearchURL=search-opensearchservi-mgtbvar5tkom-gauulqmu4nh2oub6bgdas7clhm.us-east-1.es.amazonaws.com&param_SagemakerEndpoint=semantic-search-model-1664417013&param_LambdaZipFile=s3://static-cloudformation-semantic-s-s3buckettraining-zx4sh9dbq4sd/lambda/lambda.zip

# %% [markdown]
# ## Once the CloudFormation Stack shows CREATE_COMPLETE, proceed to this cell below:

# %%
import json
api_endpoint = get_cfn_outputs('semantic-search-api')['TextSimilarityApi']

with open('./frontend/src/config/config.json', 'w') as outfile:
    json.dump({'apiEndpoint': api_endpoint}, outfile)

# %% [markdown]
# ## Deploy frontend services

# %%
# add NPM to the path so we can assemble the web frontend from our notebook code

from os import environ

npm_path = ':/home/ec2-user/anaconda3/envs/JupyterSystemEnv/bin'

if npm_path not in environ['PATH']:
    ADD_NPM_PATH = environ['PATH']
    ADD_NPM_PATH = ADD_NPM_PATH + npm_path
else:
    ADD_NPM_PATH = environ['PATH']
    
# %set_env PATH=$ADD_NPM_PATH

# %%
# %cd ./frontend/

# !npm install

# %%
# !npm run-script build

# %%
hosting_bucket = f"s3://{outputs['s3BucketHostingBucketName']}"

# !aws s3 sync ./build/ $hosting_bucket --acl public-read

# %% [markdown]
# ## Browse your frontend service

# %%
print('Click the URL below:\n')
print(outputs['S3BucketSecureURL'] + '/index.html')

# %% [markdown]
# You can search the question, for example "does this work with xbox?", compare the search result. you will see the difference between keyword search and semantic search.
#
# ![full stack semantic search](full-stack-semantic-search-ui.jpg)
#
# In keyword search, some questions like "Does this work for a switch?", "does this work with pc" which include "does this work" are searched however the meaning is totally different with query.
#
# In semantic search, some questions like "Do I need to buy anything extra to used in xbox one s controller?", "How do these headphones connect to the Xbox360 controller?" are searched. The meaning is very close to the query.
# ![full stack semantic search](full-stack-semantic-search-ui-2.jpg)

# %% [markdown]
# ## Cleanup
#
# Make sure that you stop the notebook instance, delete the Amazon SageMaker endpoint and delete the Elasticsearch domain to prevent any additional charges.

# %%
# Delete the endpoint
predictor.delete_endpoint()

# Empty S3 Contents
training_bucket_resource = s3_resource.Bucket(bucket)
training_bucket_resource.objects.all().delete()

hosting_bucket_resource = s3_resource.Bucket(outputs['s3BucketHostingBucketName'])
hosting_bucket_resource.objects.all().delete()
